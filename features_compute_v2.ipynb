# %%
from main import get_miner
from log_parsing import from_id_to_template
import joblib
from data_integrate import *
from pattern_miner import *
from pattern_ranker2 import *
import pandas as pd

# %%
log_template_miner = get_miner()

# %%
res_dict = joblib.load('output/fault_free_eventgraphs.joblib')

# %%
res_dict2 = joblib.load('output/fault_suffering_eventgraphs.joblib')

# %%
res_dict2.keys()
# Out:
# dict_keys(['2022-08-22 03:54', '2022-08-22 03:55', '2022-08-22 04:03', '2022-08-22 04:04', '2022-08-22 04:11', '2022-08-22 04:12', '2022-08-22 04:19', '2022-08-22 04:20', '2022-08-22 04:28', '2022-08-22 04:29', '2022-08-22 04:37', '2022-08-22 04:38', '2022-08-22 04:45', '2022-08-22 04:46', '2022-08-22 04:53', '2022-08-22 04:54', '2022-08-22 05:02', '2022-08-22 05:03', '2022-08-22 05:10', '2022-08-22 05:11', '2022-08-22 05:19', '2022-08-22 05:20', '2022-08-22 05:28', '2022-08-22 05:29', '2022-08-22 05:36', '2022-08-22 05:37', '2022-08-22 05:44', '2022-08-22 05:45', '2022-08-22 05:53', '2022-08-22 05:54', '2022-08-22 06:02', '2022-08-22 06:03', '2022-08-22 06:36', '2022-08-22 06:37', '2022-08-22 06:53', '2022-08-22 06:54', '2022-08-22 07:02', '2022-08-22 07:03', '2022-08-22 07:11', '2022-08-22 07:12', '2022-08-22 07:18', '2022-08-22 07:19', '2022-08-22 07:27', '2022-08-22 07:28', '2022-08-22 07:45', '2022-08-22 07:46', '2022-08-22 07:54', '2022-08-22 07:55', '2022-08-23 12:02', '2022-08-23 12:03', '2022-08-23 12:11', '2022-08-23 12:12', '2022-08-23 12:19', '2022-08-23 12:20', '2022-08-23 12:28', '2022-08-23 12:29', '2022-08-23 12:36', '2022-08-23 12:37', '2022-08-23 12:46', '2022-08-23 12:47', '2022-08-23 12:54', '2022-08-23 12:55', '2022-08-23 13:03', '2022-08-23 13:04', '2022-08-23 13:11', '2022-08-23 13:12', '2022-08-23 13:20', '2022-08-23 13:21', '2022-08-23 13:28', '2022-08-23 13:29', '2022-08-23 13:38', '2022-08-23 13:39', '2022-08-23 13:46', '2022-08-23 13:47', '2022-08-23 13:55', '2022-08-23 13:56', '2022-08-23 14:04', '2022-08-23 14:05', '2022-08-23 14:13', '2022-08-23 14:14', '2022-08-23 14:22', '2022-08-23 14:23', '2022-08-23 14:31', '2022-08-23 14:32', '2022-08-23 14:48', '2022-08-23 14:49', '2022-08-23 14:56', '2022-08-23 14:57', '2022-08-23 15:05', '2022-08-23 15:06', '2022-08-23 15:13', '2022-08-23 15:14', '2022-08-23 15:22', '2022-08-23 15:23', '2022-08-23 15:30', '2022-08-23 15:31', '2022-08-23 15:39', '2022-08-23 15:40', '2022-08-23 15:48', '2022-08-23 15:49', '2022-08-23 15:57', '2022-08-23 15:58', '2022-08-23 16:06', '2022-08-23 16:07', '2022-08-23 16:14', '2022-08-23 16:15', '2022-08-23 16:23', '2022-08-23 16:24', '2022-08-23 16:32', '2022-08-23 16:33', '2022-08-23 16:41', '2022-08-23 16:42'])

# %%
abnormal_dates = res_dict2.keys()

# %%
abnormal_dates = res_dict2.keys()
features_labeled = []
for normal_date in res_dict.keys():
    date = normal_date.split(' ')[0]
    fault_free_pattern = get_pattern_support(res_dict[normal_date])
    print(date)
    for abnormal_date in [d for d in abnormal_dates if d.split(' ')[0] == date]:
        print(abnormal_date)
        fault_suffering_event_graphs = res_dict2[abnormal_date]['event_graphs']
        fault_suffering_pattern = get_pattern_support(fault_suffering_event_graphs)
        ranking = pattern_ranker_custom(fault_free_pattern, fault_suffering_event_graphs, fault_suffering_pattern, log_template_miner)
        res = { 
               'abnormal_time': abnormal_date,
               'abnormalpattern_noerror_ranked': ranking[0],
               'abnormalpattern_error_ranked': ranking[1], 
               'inject_time': res_dict2[abnormal_date]['inject_time'],
               'inject_pod': res_dict2[abnormal_date]['inject_pod'], 
               'inject_type': res_dict2[abnormal_date]['inject_type'],
            }
        features_labeled.append(res)

# %%
features_labeled
# Out:
# [{'abnormal_time': '2022-08-22 03:54',
#   'abnormalpattern_noerror_ranked': [{'events': '5_12',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_67',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_184',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_6',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_8',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_10',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_85',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_14',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_77',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_101',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 03:53:54',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 03:55',
#   'abnormalpattern_noerror_ranked': [{'events': '5_12',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_67',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_184',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_6',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_8',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_10',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_85',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_14',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_77',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_101',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 03:53:54',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 04:03',
#   'abnormalpattern_noerror_ranked': [{'events': '186_82',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '97_98',
#     'score': -0.7082352941176471,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '83_84',
#     'score': -0.6457142857142857,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_86',
#     'score': -0.6457142857142857,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_87',
#     'score': -0.6457142857142857,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '90_91',
#     'score': -0.6457142857142857,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '10_11',
#     'score': -0.476482617586912,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '10_26',
#     'score': -0.476482617586912,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '30_31',
#     'score': -0.476482617586912,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '30_32',
#     'score': -0.476482617586912,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'}],
#   'inject_time': '2022-08-22 04:02:07',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-22 04:04',
#   'abnormalpattern_noerror_ranked': [{'events': '186_82',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '97_98',
#     'score': -0.6962616822429907,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '83_84',
#     'score': -0.631728045325779,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_86',
#     'score': -0.631728045325779,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_87',
#     'score': -0.631728045325779,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '90_91',
#     'score': -0.631728045325779,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '10_11',
#     'score': -0.43253968253968256,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '10_26',
#     'score': -0.43253968253968256,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '30_31',
#     'score': -0.43253968253968256,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '30_32',
#     'score': -0.43253968253968256,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'}],
#   'inject_time': '2022-08-22 04:02:07',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-22 04:11',
#   'abnormalpattern_noerror_ranked': [{'events': '5_12',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_67',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_184',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_6',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_8',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_10',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_85',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_14',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_77',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_101',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:10:20',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'cpu_consumed'},
#  {'abnormal_time': '2022-08-22 04:12',
#   'abnormalpattern_noerror_ranked': [{'events': '5_12',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_67',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_184',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_6',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_8',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_10',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_85',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_14',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_101',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '5_77',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:10:20',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'cpu_consumed'},
#  {'abnormal_time': '2022-08-22 04:19',
#   'abnormalpattern_noerror_ranked': [{'events': '2_109',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_107',
#     'score': 0.21621621621621623,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '121_122',
#     'score': 0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '106_92',
#     'score': 0.07964601769911495,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': 0.07964601769911495,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '84_100',
#     'score': 0.07964601769911495,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '84_82'},
#    {'events': '101_102',
#     'score': 0.07964601769911495,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '101_32',
#     'score': 0.07964601769911495,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_103',
#     'score': 0.07964601769911495,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '89_90'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'}],
#   'inject_time': '2022-08-22 04:18:35',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-22 04:20',
#   'abnormalpattern_noerror_ranked': [{'events': '121_122',
#     'score': 0.2149532710280373,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.2149532710280373,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.20529801324503305,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '110_4',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_112',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': 0.18181818181818188,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'}],
#   'inject_time': '2022-08-22 04:18:35',
#   'inject_pod': 'frontend-579b9bff58-t2dbm',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-22 04:28',
#   'abnormalpattern_noerror_ranked': [{'events': '2_107',
#     'score': 0.10769230769230775,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_109',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '129_130',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '129_169',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '131_132',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '131_179',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '133_134',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '137_138',
#     'score': -0.09090909090909094,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:27:03',
#   'inject_pod': 'cartservice-579f59597d-wc2lz',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 04:29',
#   'abnormalpattern_noerror_ranked': [{'events': '2_107',
#     'score': 0.13432835820895517,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_76',
#     'score': -0.11538461538461542,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.11538461538461542,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.11538461538461542,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_3',
#     'score': -0.08080808080808077,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '14_15',
#     'score': -0.08080808080808077,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '14_51',
#     'score': -0.08080808080808077,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '55_56',
#     'score': -0.07296137339055797,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '59_60',
#     'score': -0.07296137339055797,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '63_64',
#     'score': -0.07296137339055797,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:27:03',
#   'inject_pod': 'cartservice-579f59597d-wc2lz',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 04:37',
#   'abnormalpattern_noerror_ranked': [{'events': '25_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '81_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '170_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '2_107',
#     'score': 0.21621621621621623,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '121_122',
#     'score': 0.134020618556701,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.134020618556701,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.11764705882352944,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:36:03',
#   'inject_pod': 'cartservice-579f59597d-wc2lz',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 04:38',
#   'abnormalpattern_noerror_ranked': [{'events': '25_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '81_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '170_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'cartservice-579f59597d-wc2lz'},
#    {'events': '2_107',
#     'score': 0.1470588235294117,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '121_122',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.12408759124087587,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:36:03',
#   'inject_pod': 'cartservice-579f59597d-wc2lz',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 04:45',
#   'abnormalpattern_noerror_ranked': [{'events': '148_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_121',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_145',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '152_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '152_123',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '140_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '140_119',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '136_141',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '136_149',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'checkoutservice-578fcf4766-9csqn'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:44:16',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 04:46',
#   'abnormalpattern_noerror_ranked': [{'events': '148_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_121',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_145',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '140_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '140_119',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '144_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '152_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '152_123',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '136_137',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '136_141',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'checkoutservice-578fcf4766-9csqn'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:44:16',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 04:53',
#   'abnormalpattern_noerror_ranked': [{'events': '2_3',
#     'score': 0.08936170212765959,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '14_15',
#     'score': 0.08936170212765959,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '14_51',
#     'score': 0.08936170212765959,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_76',
#     'score': 0.08661417322834652,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': 0.08661417322834652,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.08661417322834652,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '55_56',
#     'score': 0.08424908424908417,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '59_60',
#     'score': 0.08424908424908417,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '63_64',
#     'score': 0.08424908424908417,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '106_92',
#     'score': -0.08333333333333337,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:52:55',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 04:54',
#   'abnormalpattern_noerror_ranked': [{'events': '2_107',
#     'score': 0.19444444444444442,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '121_122',
#     'score': 0.17647058823529416,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.17647058823529416,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.16666666666666674,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 04:52:55',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:02',
#   'abnormalpattern_noerror_ranked': [{'events': '113_116',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'checkoutservice-578fcf4766-9csqn',
#     'events_expected': '113_114'},
#    {'events': '121_122',
#     'score': 0.4042553191489362,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.4042553191489362,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.34426229508196715,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '110_4',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_112',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '153_188',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '153_154'}],
#   'inject_time': '2022-08-22 05:01:13',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-22 05:03',
#   'abnormalpattern_noerror_ranked': [{'events': '75_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '22_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_73',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '18_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '113_116',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'checkoutservice-578fcf4766-9csqn',
#     'events_expected': '113_114'},
#    {'events': '121_122',
#     'score': 0.3731343283582089,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.3731343283582089,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.2941176470588236,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '67_68',
#     'score': 0.14524905818334033,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '153_188',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '153_154'}],
#   'inject_time': '2022-08-22 05:01:13',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-22 05:10',
#   'abnormalpattern_noerror_ranked': [{'events': '113_116',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '2_109',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '113_114',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'checkoutservice-578fcf4766-9csqn'},
#    {'events': '127_128',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '127_171',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '129_130',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '129_169',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '131_132',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '131_179',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '153_154',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '153_189',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '153_154'}],
#   'inject_time': '2022-08-22 05:09:50',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-22 05:11',
#   'abnormalpattern_noerror_ranked': [{'events': '113_116',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'checkoutservice-578fcf4766-9csqn',
#     'events_expected': '113_114'},
#    {'events': '121_122',
#     'score': 0.26956521739130435,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.26956521739130435,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.21568627450980382,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_107',
#     'score': 0.10769230769230775,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_76',
#     'score': -0.07407407407407407,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.07407407407407407,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.07407407407407407,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '73_74',
#     'score': 0.07223989095865524,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '67_68',
#     'score': 0.07223989095865524,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '2_185',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '153_189',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '153_154'}],
#   'inject_time': '2022-08-22 05:09:50',
#   'inject_pod': 'checkoutservice-578fcf4766-9csqn',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-22 05:19',
#   'abnormalpattern_noerror_ranked': [{'events': '75_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '22_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_73',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '18_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '2_109',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.6363636363636364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:18:09',
#   'inject_pod': 'currencyservice-cf787dd48-vpjrd',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 05:20',
#   'abnormalpattern_noerror_ranked': [{'events': '75_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '22_184',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_73',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '72_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '18_19',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'currencyservice-cf787dd48-vpjrd'},
#    {'events': '2_82',
#     'score': -0.728937728937729,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '84_82',
#     'score': -0.728937728937729,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_90',
#     'score': -0.728937728937729,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '96_92',
#     'score': -0.7134986225895317,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '91_93',
#     'score': -0.7134986225895317,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:18:09',
#   'inject_pod': 'currencyservice-cf787dd48-vpjrd',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 05:28',
#   'abnormalpattern_noerror_ranked': [{'events': '96_92',
#     'score': -0.26166328600405675,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '91_93',
#     'score': -0.26166328600405675,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '73_74',
#     'score': -0.24740378741600488,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '67_68',
#     'score': -0.24740378741600488,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '67_69',
#     'score': -0.24740378741600488,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_82',
#     'score': -0.2453825857519789,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '84_82',
#     'score': -0.2453825857519789,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_90',
#     'score': -0.2453825857519789,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_86',
#     'score': -0.24406047516198703,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '85_87',
#     'score': -0.24406047516198703,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:27:06',
#   'inject_pod': 'currencyservice-cf787dd48-vpjrd',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:29',
#   'abnormalpattern_noerror_ranked': [{'events': '121_122',
#     'score': -0.3125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': -0.3125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_76',
#     'score': -0.3033707865168539,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_78',
#     'score': -0.3033707865168539,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.3033707865168539,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '96_92',
#     'score': -0.2958333333333333,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '91_93',
#     'score': -0.2958333333333333,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_82',
#     'score': -0.2896174863387978,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '84_82',
#     'score': -0.2896174863387978,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_90',
#     'score': -0.2896174863387978,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:27:06',
#   'inject_pod': 'currencyservice-cf787dd48-vpjrd',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:36',
#   'abnormalpattern_noerror_ranked': [{'events': '182_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'emailservice-55fdc5b988-f6xth'},
#    {'events': '2_109',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_126',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_175',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:35:34',
#   'inject_pod': 'emailservice-55fdc5b988-f6xth',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 05:37',
#   'abnormalpattern_noerror_ranked': [{'events': '182_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'emailservice-55fdc5b988-f6xth'},
#    {'events': '2_76',
#     'score': -0.09433962264150941,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.09433962264150941,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.09433962264150941,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_122',
#     'score': 0.08695652173913038,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.08695652173913038,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_107',
#     'score': 0.06451612903225801,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_109',
#     'score': 0.05263157894736836,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.05263157894736836,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:35:34',
#   'inject_pod': 'emailservice-55fdc5b988-f6xth',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 05:44',
#   'abnormalpattern_noerror_ranked': [{'events': '2_76',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '106_92',
#     'score': -0.040000000000000036,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '84_100',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '84_82'},
#    {'events': '101_102',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '101_32',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_103',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '89_90'},
#    {'events': '91_105',
#     'score': -0.040000000000000036,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '91_93'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:43:48',
#   'inject_pod': 'emailservice-55fdc5b988-f6xth',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:45',
#   'abnormalpattern_noerror_ranked': [{'events': '2_107',
#     'score': 0.1212121212121211,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_76',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.06422018348623848,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '96_92',
#     'score': 0.05182926829268286,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '91_93',
#     'score': 0.05182926829268286,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '121_122',
#     'score': 0.045454545454545414,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.045454545454545414,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '106_92',
#     'score': 0.03703703703703698,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': 0.03703703703703698,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:43:48',
#   'inject_pod': 'emailservice-55fdc5b988-f6xth',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:53',
#   'abnormalpattern_noerror_ranked': [{'events': '2_76',
#     'score': -0.13725490196078427,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': -0.13725490196078427,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': -0.13725490196078427,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_107',
#     'score': 0.049180327868852514,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_109',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': -0.02857142857142858,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:52:54',
#   'inject_pod': 'paymentservice-9cdb6588f-554sm',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 05:54',
#   'abnormalpattern_noerror_ranked': [{'events': '121_122',
#     'score': 0.134020618556701,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.134020618556701,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.11111111111111116,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_107',
#     'score': 0.10769230769230775,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_3',
#     'score': 0.06550218340611358,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '14_15',
#     'score': 0.06550218340611358,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '14_51',
#     'score': 0.06550218340611358,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '55_56',
#     'score': 0.06367041198501866,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '59_60',
#     'score': 0.06367041198501866,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '63_64',
#     'score': 0.06367041198501866,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 05:52:54',
#   'inject_pod': 'paymentservice-9cdb6588f-554sm',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-22 06:02',
#   'abnormalpattern_noerror_ranked': [{'events': '178_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'paymentservice-9cdb6588f-554sm'},
#    {'events': '121_122',
#     'score': 0.17647058823529416,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.17647058823529416,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': 0.13669064748201443,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_3',
#     'score': 0.0815450643776825,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '14_15',
#     'score': 0.0815450643776825,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '14_51',
#     'score': 0.0815450643776825,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_107',
#     'score': 0.0793650793650793,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '55_56',
#     'score': 0.07407407407407418,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '59_60',
#     'score': 0.07407407407407418,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 06:01:18',
#   'inject_pod': 'paymentservice-9cdb6588f-554sm',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 06:03',
#   'abnormalpattern_noerror_ranked': [{'events': '178_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'paymentservice-9cdb6588f-554sm'},
#    {'events': '2_109',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_126',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_175',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 06:01:18',
#   'inject_pod': 'paymentservice-9cdb6588f-554sm',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-22 06:36',
#   'abnormalpattern_noerror_ranked': [{'events': '46_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '46_47',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '46_49',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '42_43',
#     'score': 1.0,
#     'deepth': 3,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '38_47',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '38_49',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '35_39',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '106_92',
#     'score': -0.11827956989247312,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': -0.11827956989247312,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '84_100',
#     'score': -0.11827956989247312,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '84_82'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-22 06:35:39',
#   'inject_pod': 'productcatalogservice-668d5f85fb-wckp8',
#   'inject_type': 'cpu_consumed'},
#  {'abnormal_time': '2022-08-22 06:37',
#   'abnormalpattern_noerror_ranked': [{'events': '46_184',
#     'score': 1.0,
#     'deepth': 4,
#     'pod': 'productcatalogservice-668d5f85fb-wckp8'},
#    {'events': '46_47',
#     'score': 1.0,
# ...
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '2_76',
#     'score': 0.07843137254901955,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': 0.07843137254901955,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.07843137254901955,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_122',
#     'score': 0.07070707070707072,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 15:56:24',
#   'inject_pod': 'shippingservice-7b598fc7d-lmggd',
#   'inject_type': 'cpu_consumed'},
#  {'abnormal_time': '2022-08-23 16:06',
#   'abnormalpattern_noerror_ranked': [{'events': '2_109',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_126',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_175',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '127_128',
#     'score': -0.125,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:05:02',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-23 16:07',
#   'abnormalpattern_noerror_ranked': [{'events': '2_109',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_126',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_175',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '127_128',
#     'score': -0.19999999999999996,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:05:02',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'network_delay'},
#  {'abnormal_time': '2022-08-23 16:14',
#   'abnormalpattern_noerror_ranked': [{'events': '2_84',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '106_92',
#     'score': -0.36708860759493667,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': -0.36708860759493667,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '89_103',
#     'score': -0.36708860759493667,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '89_90'},
#    {'events': '91_105',
#     'score': -0.36708860759493667,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '91_93'},
#    {'events': '2_76',
#     'score': 0.21666666666666656,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': 0.21666666666666656,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.21666666666666656,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_122',
#     'score': 0.18584070796460184,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': 0.18584070796460184,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:13:38',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-23 16:15',
#   'abnormalpattern_noerror_ranked': [{'events': '2_84',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '121_122',
#     'score': -0.26027397260273977,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': -0.26027397260273977,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': -0.2549019607843137,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': -0.24137931034482762,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:13:38',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'return'},
#  {'abnormal_time': '2022-08-23 16:23',
#   'abnormalpattern_noerror_ranked': [{'events': '106_92',
#     'score': -0.33333333333333337,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '99_83',
#     'score': -0.33333333333333337,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_103',
#     'score': -0.33333333333333337,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '91_105',
#     'score': -0.33333333333333337,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '91_93'},
#    {'events': '2_76',
#     'score': 0.1132075471698113,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_78',
#     'score': 0.1132075471698113,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.1132075471698113,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_82',
#     'score': 0.048923679060665304,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '84_82',
#     'score': 0.048923679060665304,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '89_90',
#     'score': 0.048923679060665304,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '99_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '99_83'}],
#   'inject_time': '2022-08-23 16:22:53',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-23 16:24',
#   'abnormalpattern_noerror_ranked': [{'events': '2_76',
#     'score': 0.12149532710280364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': 0.12149532710280364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.12149532710280364,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '83_84',
#     'score': -0.11028037383177569,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '90_91',
#     'score': -0.11028037383177569,
#     'deepth': 1,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '2_99',
#     'score': 0.10000000000000009,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '101_102',
#     'score': 0.10000000000000009,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '101_32',
#     'score': 0.10000000000000009,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '97_98',
#     'score': -0.09063893016344726,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft'},
#    {'events': '121_122',
#     'score': 0.08000000000000007,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '99_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '99_83'}],
#   'inject_time': '2022-08-23 16:22:53',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'exception'},
#  {'abnormal_time': '2022-08-23 16:32',
#   'abnormalpattern_noerror_ranked': [{'events': '96_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '96_92'},
#    {'events': '106_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '106_92'},
#    {'events': '99_83',
#     'score': -0.36708860759493667,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '82_83',
#     'score': -0.2857142857142857,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.12195121951219523,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '82_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '82_83'},
#    {'events': '99_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '99_83'}],
#   'inject_time': '2022-08-23 16:31:35',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-23 16:33',
#   'abnormalpattern_noerror_ranked': [{'events': '96_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '96_92'},
#    {'events': '106_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '106_92'},
#    {'events': '99_83',
#     'score': -0.6119402985074627,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '82_83',
#     'score': -0.35754189944134074,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_122',
#     'score': -0.17948717948717952,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '121_36',
#     'score': -0.17948717948717952,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '145_146',
#     'score': -0.17431192660550454,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': -0.16129032258064513,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [{'events': '82_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '82_83'},
#    {'events': '99_201',
#     'score': 1.0,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '99_83'}],
#   'inject_time': '2022-08-23 16:31:35',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'cpu_contention'},
#  {'abnormal_time': '2022-08-23 16:41',
#   'abnormalpattern_noerror_ranked': [{'events': '96_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '96_92'},
#    {'events': '106_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '106_92'},
#    {'events': '2_76',
#     'score': 0.18965517241379315,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '77_78',
#     'score': 0.18965517241379315,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '77_79',
#     'score': 0.18965517241379315,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '2_109',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.07692307692307687,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:40:57',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'cpu_consumed'},
#  {'abnormal_time': '2022-08-23 16:42',
#   'abnormalpattern_noerror_ranked': [{'events': '96_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '96_92'},
#    {'events': '106_184',
#     'score': 1.0,
#     'deepth': 2,
#     'pod': 'adservice-5f6585d649-fnmft',
#     'events_expected': '106_92'},
#    {'events': '2_109',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm',
#     'events_expected': '2_82'},
#    {'events': '111_112',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '111_113',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_120',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '119_23',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_124',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '123_51',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'},
#    {'events': '125_126',
#     'score': 0.1428571428571428,
#     'deepth': 1,
#     'pod': 'frontend-579b9bff58-t2dbm'}],
#   'abnormalpattern_error_ranked': [],
#   'inject_time': '2022-08-23 16:40:57',
#   'inject_pod': 'adservice-5f6585d649-fnmft',
#   'inject_type': 'cpu_consumed'}]

# %%
# Convert to DataFrame
df = pd.DataFrame(features_labeled)
# locate templates with err or fail in string, treat them special (dont lose on ranking)

# %%
df.head()
# Out:
#       abnormal_time                     abnormalpattern_noerror_ranked  \
# 0  2022-08-22 03:54  [{'events': '5_12', 'score': 1.0, 'deepth': 1,...
# 1  2022-08-22 03:55  [{'events': '5_12', 'score': 1.0, 'deepth': 1,...
# 2  2022-08-22 04:03  [{'events': '186_82', 'score': 1.0, 'deepth': ...
# 3  2022-08-22 04:04  [{'events': '186_82', 'score': 1.0, 'deepth': ...
# 4  2022-08-22 04:11  [{'events': '5_12', 'score': 1.0, 'deepth': 1,...
#
#                         abnormalpattern_error_ranked          inject_time  \
# 0                                                 []  2022-08-22 03:53:54
# 1                                                 []  2022-08-22 03:53:54
# 2  [{'events': '2_185', 'score': 1.0, 'deepth': 1...  2022-08-22 04:02:07
# 3  [{'events': '2_185', 'score': 1.0, 'deepth': 1...  2022-08-22 04:02:07
# 4                                                 []  2022-08-22 04:10:20
#
#                   inject_pod     inject_type
# 0  frontend-579b9bff58-t2dbm  cpu_contention
# 1  frontend-579b9bff58-t2dbm  cpu_contention
# 2  frontend-579b9bff58-t2dbm          return
# 3  frontend-579b9bff58-t2dbm          return
# 4  frontend-579b9bff58-t2dbm    cpu_consumed

# %%
df.to_csv('output/features_labeled_v2.csv', index=False)
