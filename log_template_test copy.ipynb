# %%
from main import get_miner
from log_parsing import from_id_to_template
import joblib
from data_integrate import *
from pattern_miner import *
from pattern_ranker import *

# %%
log_template_miner = get_miner()

# %%
from_id_to_template(20, log_template_miner)
# Out:
# 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get currency data successful Service: currencyservice'

# %%
log_templates = []
for i in range(1, 1000):
    try:
        r = from_id_to_template(i, log_template_miner)
        if r != '':
            log_templates.append((i, r))
    except Exception as e:
        print(i, e)

# %%
log_templates
# Out:
# [(1, 'frontend hipstershop.Frontend/Recv. start Service: frontend'),
#  (2,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Request complete Service: frontend'),
#  (3,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> View user cart <:*:> Service: frontend'),
#  (4,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Request started Service: frontend'),
#  (5, 'frontend hipstershop.Frontend/Recv. end Service: frontend'),
#  (6,
#   'frontend hipstershop.CurrencyService/GetSupportedCurrencies start Service: frontend'),
#  (7,
#   'frontend hipstershop.CurrencyService/GetSupportedCurrencies end Service: frontend'),
#  (8, 'frontend hipstershop.CartService/GetCart start Service: frontend'),
#  (9, 'frontend hipstershop.CartService/GetCart end Service: frontend'),
#  (10,
#   'frontend hipstershop.RecommendationService/ListRecommendations start Service: frontend'),
#  (11,
#   'frontend hipstershop.RecommendationService/ListRecommendations end Service: frontend'),
#  (12,
#   'frontend hipstershop.ProductCatalogService/GetProduct start Service: frontend'),
#  (13,
#   'frontend hipstershop.ProductCatalogService/GetProduct end Service: frontend'),
#  (14, 'frontend hipstershop.ShippingService/GetQuote start Service: frontend'),
#  (15, 'frontend hipstershop.ShippingService/GetQuote end Service: frontend'),
#  (16,
#   'currencyservice grpc.hipstershop.CurrencyService/GetSupportedCurrencies start Service: currencyservice'),
#  (17,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Getting supported currencies... Service: currencyservice'),
#  (18,
#   'currencyservice grpc.hipstershop.CurrencyService/GetSupportedCurrencies end Service: currencyservice'),
#  (19,
#   'currencyservice hipstershop.CurrencyService/GetCurrencyData start Service: currencyservice'),
#  (20,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get currency data successful Service: currencyservice'),
#  (21,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Getting currency data Service: currencyservice'),
#  (22,
#   'currencyservice hipstershop.CurrencyService/GetCurrencyData end Service: currencyservice'),
#  (23,
#   'cartservice hipstershop.CartService/GetCart start Service: cartservice'),
#  (24,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> <:*:> called with userId=<:USERID:> Service: cartservice'),
#  (25, 'cartservice hipstershop.CartService/GetCart end Service: cartservice'),
#  (26,
#   'recommendationservice /hipstershop.RecommendationService/ListRecommendations start Service: recommendationservice'),
#  (27,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> List Recommendations product ids=<:ITEM:>'),
#  (28,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations Service: recommendationservice'),
#  (29,
#   'recommendationservice /hipstershop.RecommendationService/ListRecommendations end Service: recommendationservice'),
#  (30,
#   'recommendationservice /hipstershop.ProductCatalogService/ListProducts start Service: recommendationservice'),
#  (31,
#   'recommendationservice /hipstershop.ProductCatalogService/ListProducts end Service: recommendationservice'),
#  (32,
#   'productcatalogservice hipstershop.ProductCatalogService/ListProducts start Service: productcatalogservice'),
#  (33,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> List products end Service: productcatalogservice'),
#  (34,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start list products Service: productcatalogservice'),
#  (35,
#   'productcatalogservice hipstershop.ProductCatalogService/ListProducts end Service: productcatalogservice'),
#  (36,
#   'productcatalogservice hipstershop.ProductCatalogService/GetProduct start Service: productcatalogservice'),
#  (37,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Query product with name and description <:*:> Service: productcatalogservice'),
#  (38,
#   'productcatalogservice hipstershop.ProductCatalogService/GetProduct end Service: productcatalogservice'),
#  (39,
#   'productcatalogservice hipstershop.ProductCatalogService/ParseCatalog start Service: productcatalogservice'),
#  (40,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Parse catalog successfully Service: productcatalogservice'),
#  (41,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start parse catalog Service: productcatalogservice'),
#  (42,
#   'productcatalogservice hipstershop.ProductCatalogService/ParseCatalog end Service: productcatalogservice'),
#  (43,
#   'productcatalogservice hipstershop.ProductCatalogService/ReadCatalog start Service: productcatalogservice'),
#  (44, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> get results: <:ITEM:>'),
#  (45,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start query product catalog Service: productcatalogservice'),
#  (46,
#   'productcatalogservice hipstershop.ProductCatalogService/ReadCatalog end Service: productcatalogservice'),
#  (47,
#   'productcatalogservice sql.conn.query start Service: productcatalogservice'),
#  (48,
#   'productcatalogservice sql.conn.query end Service: productcatalogservice'),
#  (49, 'productcatalogservice sql.rows start Service: productcatalogservice'),
#  (50, 'productcatalogservice sql.rows end Service: productcatalogservice'),
#  (51,
#   'shippingservice hipstershop.ShippingService/GetQuote start Service: shippingservice'),
#  (52,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[GetQuote] completed request Service: shippingservice'),
#  (53,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[GetQuote] received request Service: shippingservice'),
#  (54,
#   'shippingservice hipstershop.ShippingService/GetQuote end Service: shippingservice'),
#  (55,
#   'shippingservice hipstershop.ShippingService/CreateQuoteFromCount start Service: shippingservice'),
#  (56,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[CreateQuoteFromCount] completed request Service: shippingservice'),
#  (57,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[CreateQuoteFromCount] received request Service: shippingservice'),
#  (58,
#   'shippingservice hipstershop.ShippingService/CreateQuoteFromCount end Service: shippingservice'),
#  (59,
#   'shippingservice hipstershop.ShippingService/QuoteByCountFloat start Service: shippingservice'),
#  (60,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[QuoteByCountFloat] completed request Service: shippingservice'),
#  (61,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[QuoteByCountFloat] received request Service: shippingservice'),
#  (62,
#   'shippingservice hipstershop.ShippingService/QuoteByCountFloat end Service: shippingservice'),
#  (63,
#   'shippingservice hipstershop.ShippingService/CreateQuoteFromFloat start Service: shippingservice'),
#  (64,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[CreateQuoteFromFloat] completed request Service: shippingservice'),
#  (65,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[CreateQuoteFromFloat] received request Service: shippingservice'),
#  (66,
#   'shippingservice hipstershop.ShippingService/CreateQuoteFromFloat end Service: shippingservice'),
#  (67, 'frontend hipstershop.CurrencyService/Convert start Service: frontend'),
#  (68, 'frontend hipstershop.CurrencyService/Convert end Service: frontend'),
#  (69,
#   'currencyservice grpc.hipstershop.CurrencyService/Convert start Service: currencyservice'),
#  (70,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Conversion request successful Service: currencyservice'),
#  (71,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Received conversion request Service: currencyservice'),
#  (72,
#   'currencyservice grpc.hipstershop.CurrencyService/Convert end Service: currencyservice'),
#  (73,
#   'currencyservice hipstershop.CurrencyService/Carry start Service: currencyservice'),
#  (74,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Handles decimal or fractional carrying Service: currencyservice'),
#  (75,
#   'currencyservice hipstershop.CurrencyService/Carry end Service: currencyservice'),
#  (76,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Adding to cart <:*:> Service: frontend'),
#  (77, 'frontend hipstershop.CartService/AddItem start Service: frontend'),
#  (78, 'frontend hipstershop.CartService/AddItem end Service: frontend'),
#  (79,
#   'cartservice hipstershop.CartService/AddItem start Service: cartservice'),
#  (80,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> AddItemAsync called with userId=<:USERID:>, productId=<:PRODUCTID:>, quantity=<:NUM:> Service: cartservice'),
#  (81, 'cartservice hipstershop.CartService/AddItem end Service: cartservice'),
#  (82,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Serving product page <:*:> Service: frontend'),
#  (83,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Choose Ad complete Service: frontend'),
#  (84,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Choose Ad started Service: frontend'),
#  (85, 'frontend hipstershop.AdService/GetAds start Service: frontend'),
#  (86, 'frontend hipstershop.AdService/GetAds end Service: frontend'),
#  (87, 'adservice hipstershop.AdService/GetAds start Service: adservice'),
#  (88, 'adservice hipstershop.AdService/GetAds end Service: adservice'),
#  (89, 'adservice hipstershop.AdServiceImpl/getAds start Service: adservice'),
#  (90,
#   '<:NUM:>:<:NUM:>:<:NUM:>.<:NUM:> INFO - TraceID: <:TRACEID:> SpanID: <:SPANID:> Received ad request (context words=<:ITEM:>'),
#  (91, 'adservice hipstershop.AdServiceImpl/getAds end Service: adservice'),
#  (92, 'MemoryUsageRate(%) Service: alarm'),
#  (93, 'adservice hipstershop.AdService/<:SPANID:> start Service: adservice'),
#  (94,
#   '<:NUM:>:<:NUM:>:<:NUM:>.<:NUM:> INFO - TraceID: <:TRACEID:> SpanID: <:SPANID:> Get Ads by Category <:*:> Service: adservice'),
#  (95,
#   '<:NUM:>:<:NUM:>:<:NUM:>.<:NUM:> INFO - TraceID: <:TRACEID:> SpanID: <:SPANID:> Query items successfully. Service: adservice'),
#  (96, 'adservice hipstershop.AdService/<:SPANID:> end Service: adservice'),
#  (97, 'adservice SELECT addatabase.aditems start Service: adservice'),
#  (98, 'adservice SELECT addatabase.aditems end Service: adservice'),
#  (99,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Request home complete Service: frontend'),
#  (100,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Request home started Service: frontend'),
#  (101,
#   'frontend hipstershop.ProductCatalogService/ListProducts start Service: frontend'),
#  (102,
#   'frontend hipstershop.ProductCatalogService/ListProducts end Service: frontend'),
#  (103,
#   '<:NUM:>:<:NUM:>:<:NUM:>.<:NUM:> INFO - TraceID: <:TRACEID:> SpanID: <:SPANID:> Constructe random Ads finish Service: adservice'),
#  (104,
#   '<:NUM:>:<:NUM:>:<:NUM:>.<:NUM:> INFO - TraceID: <:TRACEID:> SpanID: <:SPANID:> No context provided. Constructe random Ads start Service: adservice'),
#  (105,
#   'adservice hipstershop.AdService/getRandomAds start Service: adservice'),
#  (106, 'adservice hipstershop.AdService/getRandomAds end Service: adservice'),
#  (107,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Setting currency complete Service: frontend'),
#  (108,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Setting currency started Service: frontend'),
#  (109,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Order placed complete Service: frontend'),
#  (110,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Placing order started Service: frontend'),
#  (111,
#   'frontend hipstershop.CheckoutService/PlaceOrder start Service: frontend'),
#  (112,
#   'frontend hipstershop.CheckoutService/PlaceOrder end Service: frontend'),
#  (113,
#   'checkoutservice hipstershop.CheckoutService/PlaceOrder start Service: checkoutservice'),
#  (114, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> PlaceOrder user id<:ITEM:>'),
#  (115,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Payment went through (transaction id: <:*:> Service: checkoutservice'),
#  (116,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get OrderID <:USERID:> Service: checkoutservice'),
#  (117,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start PlaceOrder user id<:ITEM:>'),
#  (118,
#   'checkoutservice hipstershop.CheckoutService/PlaceOrder end Service: checkoutservice'),
#  (119,
#   'checkoutservice hipstershop.CartService/GetCart start Service: checkoutservice'),
#  (120,
#   'checkoutservice hipstershop.CartService/GetCart end Service: checkoutservice'),
#  (121,
#   'checkoutservice hipstershop.ProductCatalogService/GetProduct start Service: checkoutservice'),
#  (122,
#   'checkoutservice hipstershop.ProductCatalogService/GetProduct end Service: checkoutservice'),
#  (123,
#   'checkoutservice hipstershop.ShippingService/GetQuote start Service: checkoutservice'),
#  (124,
#   'checkoutservice hipstershop.ShippingService/GetQuote end Service: checkoutservice'),
#  (125,
#   'checkoutservice hipstershop.PaymentService/Charge start Service: checkoutservice'),
#  (126,
#   'checkoutservice hipstershop.PaymentService/Charge end Service: checkoutservice'),
#  (127,
#   'checkoutservice hipstershop.ShippingService/ShipOrder start Service: checkoutservice'),
#  (128,
#   'checkoutservice hipstershop.ShippingService/ShipOrder end Service: checkoutservice'),
#  (129,
#   'checkoutservice hipstershop.CartService/EmptyCart start Service: checkoutservice'),
#  (130,
#   'checkoutservice hipstershop.CartService/EmptyCart end Service: checkoutservice'),
#  (131,
#   'checkoutservice hipstershop.EmailService/SendOrderConfirmation start Service: checkoutservice'),
#  (132,
#   'checkoutservice hipstershop.EmailService/SendOrderConfirmation end Service: checkoutservice'),
#  (133,
#   'checkoutservice hipstershop.CheckoutService/PrepareOrderItemsAndShippingQuoteFromCart start Service: checkoutservice'),
#  (134,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Prepare order of user <:USERID:> successfully Service: checkoutservice'),
#  (135,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start prepare order of user <:USERID:> Service: checkoutservice'),
#  (136,
#   'checkoutservice hipstershop.CheckoutService/PrepareOrderItemsAndShippingQuoteFromCart end Service: checkoutservice'),
#  (137,
#   'checkoutservice hipstershop.CheckoutService/GetUserCart start Service: checkoutservice'),
#  (138,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get user <:USERID:> cart items:<:ITEM:>'),
#  (139,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Query cart of user <:USERID:> Service: checkoutservice'),
#  (140,
#   'checkoutservice hipstershop.CheckoutService/GetUserCart end Service: checkoutservice'),
#  (141,
#   'checkoutservice hipstershop.CheckoutService/PrepOrderItems start Service: checkoutservice'),
#  (142,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Query cost of products<:ITEM:>'),
#  (143,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start query cost of products<:ITEM:>'),
#  (144,
#   'checkoutservice hipstershop.CheckoutService/PrepOrderItems end Service: checkoutservice'),
#  (145,
#   'checkoutservice hipstershop.CheckoutService/ConvertCurrency start Service: checkoutservice'),
#  (146,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Convert currency from currency code:<:ITEM:>'),
#  (147,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start convert currency from currency code:<:ITEM:>'),
#  (148,
#   'checkoutservice hipstershop.CheckoutService/ConvertCurrency end Service: checkoutservice'),
#  (149,
#   'checkoutservice hipstershop.CheckoutService/QuoteShipping start Service: checkoutservice'),
#  (150,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get shipping cost currency code:<:ITEM:>'),
#  (151,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Quote shipping with items<:ITEM:>'),
#  (152,
#   'checkoutservice hipstershop.CheckoutService/QuoteShipping end Service: checkoutservice'),
#  (153,
#   'checkoutservice hipstershop.CheckoutService/ChargeCard start Service: checkoutservice'),
#  (154,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Charge successfully Service: checkoutservice'),
#  (155,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start charge card Service: checkoutservice'),
#  (156,
#   'checkoutservice hipstershop.CheckoutService/ChargeCard end Service: checkoutservice'),
#  (157,
#   'checkoutservice hipstershop.CheckoutService/ShipOrder start Service: checkoutservice'),
#  (158,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Ship Order to address street address:"<:NUM:> Amphitheatre Parkway" city:"Mountain View" state:"CA" country:"United States" zip code:<:NUM:> successfully Service: checkoutservice'),
#  (159,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start ship Order to address street address:"<:NUM:> Amphitheatre Parkway" city:"Mountain View" state:"CA" country:"United States" zip code:<:NUM:> Service: checkoutservice'),
#  (160,
#   'checkoutservice hipstershop.CheckoutService/ShipOrder end Service: checkoutservice'),
#  (161,
#   'checkoutservice hipstershop.CheckoutService/EmptyUserCart start Service: checkoutservice'),
#  (162,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Empty the cart of user <:USERID:> successfully Service: checkoutservice'),
#  (163,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start empty the cart of user <:USERID:> Service: checkoutservice'),
#  (164,
#   'checkoutservice hipstershop.CheckoutService/EmptyUserCart end Service: checkoutservice'),
#  (165,
#   'checkoutservice hipstershop.CheckoutService/SendOrderConfirmation start Service: checkoutservice'),
#  (166,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Order confirmation email sent to "someone@example.com" Service: checkoutservice'),
#  (167,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Start send Order Confirmation to email someone@example.com Service: checkoutservice'),
#  (168,
#   'checkoutservice hipstershop.CheckoutService/SendOrderConfirmation end Service: checkoutservice'),
#  (169,
#   'cartservice hipstershop.CartService/EmptyCart start Service: cartservice'),
#  (170,
#   'cartservice hipstershop.CartService/EmptyCart end Service: cartservice'),
#  (171,
#   'shippingservice hipstershop.ShippingService/ShipOrder start Service: shippingservice'),
#  (172,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[ShipOrder] completed request Service: shippingservice'),
#  (173,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:>[ShipOrder] received request Service: shippingservice'),
#  (174,
#   'shippingservice hipstershop.ShippingService/ShipOrder end Service: shippingservice'),
#  (175,
#   'paymentservice grpc.hipstershop.PaymentService/Charge start Service: paymentservice'),
#  (176,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Transaction processed: visa ending<:ITEM:>'),
#  (177,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> PaymentService#Charge invoked with request<:ITEM:>'),
#  (178,
#   'paymentservice grpc.hipstershop.PaymentService/Charge end Service: paymentservice'),
#  (179,
#   'emailservice /hipstershop.EmailService/SendOrderConfirmation start Service: emailservice'),
#  (180,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> A request to send order confirmation email to someone@example.com has been received. Service: emailservice'),
#  (181,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Send order confirmation email to someone@example.com start. Service: emailservice'),
#  (182,
#   'emailservice /hipstershop.EmailService/SendOrderConfirmation end Service: emailservice'),
#  (183,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Query product successfully Service: productcatalogservice'),
#  (184, 'CpuUsageRate(%) Service: alarm'),
#  (185,
#   'TraceID: <:TRACEID:>, SpanID: <:SPANID:> Request error Service: frontend'),
#  (186,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Product id not specified Service: frontend'),
#  (187,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to complete the order Service: frontend'),
#  (188,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to connect payment service: connect error. Service: checkoutservice'),
#  (189,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Could not charge the card: charge card error. Service: checkoutservice'),
#  (190,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": <:*:> \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> List Recommendations product ids=<:ITEM:>'),
#  (191,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": <:*:> \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.<:PRODUCTID:>"} Service: recommendationservice'),
#  (192,
#   '{"log":"Inject cpu successfullyInject cpu successfully{\\"timestamp\\": <:*:> \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> List Recommendations product ids=<:ITEM:>'),
#  (193,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.340490Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.34064974Z"} Service: recommendationservice'),
#  (194,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.845088Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.84525739Z"} Service: recommendationservice'),
#  (195,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.140843Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.14100109Z"} Service: recommendationservice'),
#  (196,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.440510Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.44068485Z"} Service: recommendationservice'),
#  (197,
#   '{"log":"Inject cpu successfullyInject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.040061Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.04024563Z"} Service: recommendationservice'),
#  (198,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.654801Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.65499791Z"} Service: recommendationservice'),
#  (199,
#   '{"log":"Inject cpu successfullyInject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.540838Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.<:PRODUCTID:>"} Service: recommendationservice'),
#  (200,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.540111Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-22T07:<:NUM:>:<:NUM:>.54026801Z"} Service: recommendationservice'),
#  (201,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to retrieve ads Service: frontend'),
#  (202,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Could not retrieve product Service: frontend'),
#  (203,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> No product with ID <:PRODUCTID:> Service: productcatalogservice'),
#  (204,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to get product recommendations Service: frontend'),
#  (205,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to convert product Service: frontend'),
#  (206,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Get user <:USERID:> cart Service: checkoutservice'),
#  (207,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to prepare order: failed to get product #"<:PRODUCTID:>" Service: checkoutservice'),
#  (208,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to get product #"<:PRODUCTID:>" Service: checkoutservice'),
#  (209,
#   'TraceID: <:TRACEID:> SpanID: <:SPANID:> failed to scan mysql query result: Query product error. Service: productcatalogservice'),
#  (210,
#   '{"log":"Inject cpu successfully{\\"timestamp\\": <:*:> \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-23T15:<:NUM:>:<:NUM:>.<:PRODUCTID:>"} Service: recommendationservice'),
#  (211,
#   '{"log":"Inject cpu successfullyInject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-23T15:<:NUM:>:<:NUM:>.240007Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-23T15:<:NUM:>:<:NUM:>.24016991Z"} Service: recommendationservice'),
#  (212,
#   '{"log":"Inject cpu successfullyInject cpu successfully{\\"timestamp\\": \\"<:NUM:>-<:NUM:>-23T15:<:NUM:>:<:NUM:>.551299Z\\", \\"severity\\": \\"INFO\\", \\"name\\": \\"recommendationservice-server\\", \\"message\\": \\"TraceID: <:TRACEID:> SpanID: <:SPANID:> Query Recommendations\\"}\\n","stream":"stdout","time":"<:NUM:>-<:NUM:>-23T15:<:NUM:>:<:NUM:>.<:PRODUCTID:>"} Service: recommendationservice')]

# %% [markdown]
# error ids:

# %%
'A'.lower()
# Out:
# 'a'

# %%
err_ids = []
for t in log_templates:
    log = t[1]
    if 'err' in log.lower() or 'fail' in log.lower() or 'exception' in log.lower():
        print(t)
        err_ids.append(t[0])
# Out:
# (185, 'TraceID: <:TRACEID:>, SpanID: <:SPANID:> Request error Service: frontend')
# (187, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to complete the order Service: frontend')
# (188, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to connect payment service: connect error. Service: checkoutservice')
# (189, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Could not charge the card: charge card error. Service: checkoutservice')
# (201, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to retrieve ads Service: frontend')
# (204, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to get product recommendations Service: frontend')
# (205, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to convert product Service: frontend')
# (207, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to prepare order: failed to get product #"<:PRODUCTID:>" Service: checkoutservice')
# (208, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> Failed to get product #"<:PRODUCTID:>" Service: checkoutservice')
# (209, 'TraceID: <:TRACEID:> SpanID: <:SPANID:> failed to scan mysql query result: Query product error. Service: productcatalogservice')

# %%
err_ids
# Out:
# [185, 187, 188, 189, 201, 204, 205, 207, 208, 209]

# %%
res_dict = joblib.load('output/fault_free_eventgraphs.joblib')

# %%
res_dict
# Out:
# {'2022-08-22 03:51': [<data_integrate.EventGraph at 0x240f7477790>,
#   <data_integrate.EventGraph at 0x240f752f1f0>,
#   <data_integrate.EventGraph at 0x240f752fe80>,
#   <data_integrate.EventGraph at 0x240f759dcd0>,
#   <data_integrate.EventGraph at 0x240f75d8370>,
#   <data_integrate.EventGraph at 0x240f75df040>,
#   <data_integrate.EventGraph at 0x240f75fb6d0>,
#   <data_integrate.EventGraph at 0x240f761ad30>,
#   <data_integrate.EventGraph at 0x240f7621a00>,
#   <data_integrate.EventGraph at 0x240f76450a0>,
#   <data_integrate.EventGraph at 0x240f7661bb0>,
#   <data_integrate.EventGraph at 0x240f768d610>,
#   <data_integrate.EventGraph at 0x240f76bc040>,
#   <data_integrate.EventGraph at 0x240f76da6a0>,
#   <data_integrate.EventGraph at 0x240f76f7d00>,
#   <data_integrate.EventGraph at 0x240f771c3a0>,
#   <data_integrate.EventGraph at 0x240f7740310>,
#   <data_integrate.EventGraph at 0x240f7770100>,
#   <data_integrate.EventGraph at 0x240f7793070>,
#   <data_integrate.EventGraph at 0x240f7793d00>,
#   <data_integrate.EventGraph at 0x240f77b73a0>,
#   <data_integrate.EventGraph at 0x240f77d7a00>,
#   <data_integrate.EventGraph at 0x240f77d7dc0>,
#   <data_integrate.EventGraph at 0x240f794a910>,
#   <data_integrate.EventGraph at 0x240f796e460>,
#   <data_integrate.EventGraph at 0x240f7999310>,
#   <data_integrate.EventGraph at 0x240f79b7970>,
#   <data_integrate.EventGraph at 0x240f79da4c0>,
#   <data_integrate.EventGraph at 0x240f79e2190>,
#   <data_integrate.EventGraph at 0x240f79fe7f0>,
#   <data_integrate.EventGraph at 0x240f7a23340>,
#   <data_integrate.EventGraph at 0x240f7a472b0>,
#   <data_integrate.EventGraph at 0x240f7a6bfa0>,
#   <data_integrate.EventGraph at 0x240f7a90640>,
#   <data_integrate.EventGraph at 0x240f7ab35b0>,
#   <data_integrate.EventGraph at 0x240f7ab3970>,
#   <data_integrate.EventGraph at 0x240f7ad3fd0>,
#   <data_integrate.EventGraph at 0x240f7af7b20>,
#   <data_integrate.EventGraph at 0x240f7b1a1c0>,
#   <data_integrate.EventGraph at 0x240f7b39cd0>,
#   <data_integrate.EventGraph at 0x240f7b409a0>,
#   <data_integrate.EventGraph at 0x240f7b63910>,
#   <data_integrate.EventGraph at 0x240f7b82f70>,
#   <data_integrate.EventGraph at 0x240f7bb0d60>,
#   <data_integrate.EventGraph at 0x240f7bd58b0>,
#   <data_integrate.EventGraph at 0x240f77e5400>,
#   <data_integrate.EventGraph at 0x240f7801a60>,
#   <data_integrate.EventGraph at 0x240f7801e20>,
#   <data_integrate.EventGraph at 0x240f78264c0>,
#   <data_integrate.EventGraph at 0x240f7844b20>,
#   <data_integrate.EventGraph at 0x240f7873550>,
#   <data_integrate.EventGraph at 0x240f789d400>,
#   <data_integrate.EventGraph at 0x240f78a50d0>,
#   <data_integrate.EventGraph at 0x240f78a5490>,
#   <data_integrate.EventGraph at 0x240f78c2af0>,
#   <data_integrate.EventGraph at 0x240f78c2eb0>,
#   <data_integrate.EventGraph at 0x240f78e7e20>,
#   <data_integrate.EventGraph at 0x240f790b4c0>,
#   <data_integrate.EventGraph at 0x240f7e94370>,
#   <data_integrate.EventGraph at 0x240f7eb92e0>,
#   <data_integrate.EventGraph at 0x240f7ed6940>,
#   <data_integrate.EventGraph at 0x240f7ed6d00>,
#   <data_integrate.EventGraph at 0x240f7edf9d0>,
#   <data_integrate.EventGraph at 0x240f7f01070>,
#   <data_integrate.EventGraph at 0x240f7f20b80>,
#   <data_integrate.EventGraph at 0x240f7f43220>,
#   <data_integrate.EventGraph at 0x240f7f63850>,
#   <data_integrate.EventGraph at 0x240f7f94640>,
#   <data_integrate.EventGraph at 0x240f7fb2ca0>,
#   <data_integrate.EventGraph at 0x240f7fd57f0>,
#   <data_integrate.EventGraph at 0x240f7ff3e50>,
#   <data_integrate.EventGraph at 0x240f80174f0>,
#   <data_integrate.EventGraph at 0x240f803c040>,
#   <data_integrate.EventGraph at 0x240f80596a0>,
#   <data_integrate.EventGraph at 0x240f80776d0>,
#   <data_integrate.EventGraph at 0x240f8097d30>,
#   <data_integrate.EventGraph at 0x240f80c6760>,
#   <data_integrate.EventGraph at 0x240f80f4190>,
#   <data_integrate.EventGraph at 0x240f80f4e20>,
#   <data_integrate.EventGraph at 0x240f81194c0>,
#   <data_integrate.EventGraph at 0x240f8137b20>,
#   <data_integrate.EventGraph at 0x240f81609d0>,
#   <data_integrate.EventGraph at 0x240f8185070>,
#   <data_integrate.EventGraph at 0x240f81aea90>,
#   <data_integrate.EventGraph at 0x240f81c1820>,
#   <data_integrate.EventGraph at 0x240f81d14f0>,
#   <data_integrate.EventGraph at 0x240f81f6040>,
#   <data_integrate.EventGraph at 0x240f821ea30>,
#   <data_integrate.EventGraph at 0x240f824e460>,
#   <data_integrate.EventGraph at 0x240f8277e50>,
#   <data_integrate.EventGraph at 0x240f829a9a0>,
#   <data_integrate.EventGraph at 0x240f82bf040>,
#   <data_integrate.EventGraph at 0x240f82dc6a0>,
#   <data_integrate.EventGraph at 0x240f82fcd00>,
#   <data_integrate.EventGraph at 0x240f7bf39d0>,
#   <data_integrate.EventGraph at 0x240f7c16520>,
#   <data_integrate.EventGraph at 0x240f7c453a0>,
#   <data_integrate.EventGraph at 0x240f7c64a00>,
#   <data_integrate.EventGraph at 0x240f7c6a6d0>,
#   <data_integrate.EventGraph at 0x240f7c8e220>,
#   <data_integrate.EventGraph at 0x240f7cb80d0>,
#   <data_integrate.EventGraph at 0x240f7cb8d60>,
#   <data_integrate.EventGraph at 0x240f7ce8790>,
#   <data_integrate.EventGraph at 0x240f7d07df0>,
#   <data_integrate.EventGraph at 0x240f7d2a940>,
#   <data_integrate.EventGraph at 0x240f7d49fa0>,
#   <data_integrate.EventGraph at 0x240f7d6caf0>,
#   <data_integrate.EventGraph at 0x240f7d90190>,
#   <data_integrate.EventGraph at 0x240f7daeca0>,
#   <data_integrate.EventGraph at 0x240f7dd2340>,
#   <data_integrate.EventGraph at 0x240f7df1e50>,
#   <data_integrate.EventGraph at 0x240f7e154f0>,
#   <data_integrate.EventGraph at 0x240f7e3fee0>,
#   <data_integrate.EventGraph at 0x240f7e63580>,
#   <data_integrate.EventGraph at 0x240f88264f0>,
#   <data_integrate.EventGraph at 0x240f8845b50>,
#   <data_integrate.EventGraph at 0x240f88686a0>,
#   <data_integrate.EventGraph at 0x240f8897490>,
#   <data_integrate.EventGraph at 0x240f88c8280>,
#   <data_integrate.EventGraph at 0x240f88e6d90>,
#   <data_integrate.EventGraph at 0x240f88eda60>,
#   <data_integrate.EventGraph at 0x240f8915910>,
#   <data_integrate.EventGraph at 0x240f8953040>,
#   <data_integrate.EventGraph at 0x240f896f6a0>,
#   <data_integrate.EventGraph at 0x240f898ed00>,
#   <data_integrate.EventGraph at 0x240f89b2850>,
#   <data_integrate.EventGraph at 0x240f89d0eb0>,
#   <data_integrate.EventGraph at 0x240f89ff8e0>,
#   <data_integrate.EventGraph at 0x240f8a2e6d0>,
#   <data_integrate.EventGraph at 0x240f8a53220>,
#   <data_integrate.EventGraph at 0x240f8a71880>,
#   <data_integrate.EventGraph at 0x240f8a9a730>,
#   <data_integrate.EventGraph at 0x240f8ab8d90>,
#   <data_integrate.EventGraph at 0x240f8abfa60>,
#   <data_integrate.EventGraph at 0x240f8ae2100>,
#   <data_integrate.EventGraph at 0x240f8b01760>,
#   <data_integrate.EventGraph at 0x240f8b252b0>,
#   <data_integrate.EventGraph at 0x240f8b43910>,
#   <data_integrate.EventGraph at 0x240f8b74340>,
#   <data_integrate.EventGraph at 0x240f8b74fd0>,
#   <data_integrate.EventGraph at 0x240f8b97670>,
#   <data_integrate.EventGraph at 0x240f8bb6cd0>,
#   <data_integrate.EventGraph at 0x240f8bdfb80>,
#   <data_integrate.EventGraph at 0x240f8c02220>,
#   <data_integrate.EventGraph at 0x240f8c21d30>,
#   <data_integrate.EventGraph at 0x240f8c45880>,
#   <data_integrate.EventGraph at 0x240f8c63ee0>,
#   <data_integrate.EventGraph at 0x240f8c9f580>,
#   <data_integrate.EventGraph at 0x240f8cbcbe0>,
#   <data_integrate.EventGraph at 0x240f8ce1280>,
#   <data_integrate.EventGraph at 0x240f8d0a130>,
#   <data_integrate.EventGraph at 0x240f8d28160>,
#   <data_integrate.EventGraph at 0x240f8d46c70>,
#   <data_integrate.EventGraph at 0x240f8d77a60>,
#   <data_integrate.EventGraph at 0x240f8d95a90>,
#   <data_integrate.EventGraph at 0x240f8d95e50>,
#   <data_integrate.EventGraph at 0x240f8dc5cd0>,
#   <data_integrate.EventGraph at 0x240f8deb370>,
#   <data_integrate.EventGraph at 0x240f8e099d0>,
#   <data_integrate.EventGraph at 0x240f8e39400>,
#   <data_integrate.EventGraph at 0x240f8e56a60>,
#   <data_integrate.EventGraph at 0x240f8e85490>,
#   <data_integrate.EventGraph at 0x240f8ec03d0>,
#   <data_integrate.EventGraph at 0x240f8ec80a0>,
#   <data_integrate.EventGraph at 0x240f8ef2ee0>,
#   <data_integrate.EventGraph at 0x240f8f17580>,
#   <data_integrate.EventGraph at 0x240f8f36be0>,
#   <data_integrate.EventGraph at 0x240f8f58b50>,
#   <data_integrate.EventGraph at 0x240f8f7d1f0>,
#   <data_integrate.EventGraph at 0x240f8fa6be0>,
#   <data_integrate.EventGraph at 0x240f8fca280>,
#   <data_integrate.EventGraph at 0x240f8fe98e0>,
#   <data_integrate.EventGraph at 0x240f900b850>,
#   <data_integrate.EventGraph at 0x240f902aeb0>,
#   <data_integrate.EventGraph at 0x240f9049ee0>,
#   <data_integrate.EventGraph at 0x240f906e580>,
#   <data_integrate.EventGraph at 0x240f90914f0>,
#   <data_integrate.EventGraph at 0x240f90b6460>,
#   <data_integrate.EventGraph at 0x240f90bc130>,
#   <data_integrate.EventGraph at 0x240f90bc4f0>,
#   <data_integrate.EventGraph at 0x240f90eb370>,
#   <data_integrate.EventGraph at 0x240f8305d60>,
#   <data_integrate.EventGraph at 0x240f8324d90>,
#   <data_integrate.EventGraph at 0x240f8349430>,
#   <data_integrate.EventGraph at 0x240f8377220>,
#   <data_integrate.EventGraph at 0x240f83ad880>,
#   <data_integrate.EventGraph at 0x240f83d13a0>,
#   <data_integrate.EventGraph at 0x240f83ef400>,
#   <data_integrate.EventGraph at 0x240f840da60>,
#   <data_integrate.EventGraph at 0x240f843d490>,
#   <data_integrate.EventGraph at 0x240f845aaf0>,
#   <data_integrate.EventGraph at 0x240f847e190>,
#   <data_integrate.EventGraph at 0x240f84a8b80>,
#   <data_integrate.EventGraph at 0x240f84d1a30>,
#   <data_integrate.EventGraph at 0x240f84f60d0>,
#   <data_integrate.EventGraph at 0x240f8514730>,
#   <data_integrate.EventGraph at 0x240f8537280>,
#   <data_integrate.EventGraph at 0x240f85558e0>,
#   <data_integrate.EventGraph at 0x240f857ff10>,
#   <data_integrate.EventGraph at 0x240f85a55b0>,
#   <data_integrate.EventGraph at 0x240f85c3c10>,
#   <data_integrate.EventGraph at 0x240f85e82b0>,
#   <data_integrate.EventGraph at 0x240f8611160>,
#   <data_integrate.EventGraph at 0x240f8611df0>,
#   <data_integrate.EventGraph at 0x240f8618ac0>,
#   <data_integrate.EventGraph at 0x240f863d160>,
#   <data_integrate.EventGraph at 0x240f8666b50>,
#   <data_integrate.EventGraph at 0x240f866e820>,
#   <data_integrate.EventGraph at 0x240f8690370>,
#   <data_integrate.EventGraph at 0x240f86b9220>,
#   <data_integrate.EventGraph at 0x240f86d9880>,
#   <data_integrate.EventGraph at 0x240f8703730>,
#   <data_integrate.EventGraph at 0x240f872d5e0>,
#   <data_integrate.EventGraph at 0x240f87332b0>,
#   <data_integrate.EventGraph at 0x240f8751dc0>,
#   <data_integrate.EventGraph at 0x240f8786490>,
#   <data_integrate.EventGraph at 0x240f878e160>,
#   <data_integrate.EventGraph at 0x240f87aa7c0>,
#   <data_integrate.EventGraph at 0x240f87c9e20>,
#   <data_integrate.EventGraph at 0x240f87d1af0>,
#   <data_integrate.EventGraph at 0x240f87d1eb0>,
#   <data_integrate.EventGraph at 0x240f87d72b0>,
#   <data_integrate.EventGraph at 0x240f9b270a0>,
#   <data_integrate.EventGraph at 0x240f9b50a90>,
#   <data_integrate.EventGraph at 0x240f9b73130>,
#   <data_integrate.EventGraph at 0x240f9b91c40>,
#   <data_integrate.EventGraph at 0x240f9bb6790>,
#   <data_integrate.EventGraph at 0x240f9bd4df0>,
#   <data_integrate.EventGraph at 0x240f9bda1f0>,
#   <data_integrate.EventGraph at 0x240f9bda5b0>,
#   <data_integrate.EventGraph at 0x240f9bf9c10>,
#   <data_integrate.EventGraph at 0x240f9c1c2b0>,
#   <data_integrate.EventGraph at 0x240f9c3b910>,
#   <data_integrate.EventGraph at 0x240f9c657f0>,
#   <data_integrate.EventGraph at 0x240f9c941f0>,
#   <data_integrate.EventGraph at 0x240f9cb2220>,
#   <data_integrate.EventGraph at 0x240f9cd1d30>,
#   <data_integrate.EventGraph at 0x240f9cf4ca0>,
#   <data_integrate.EventGraph at 0x240f9d197f0>,
#   <data_integrate.EventGraph at 0x240f9d4de50>,
#   <data_integrate.EventGraph at 0x240f9d56b20>,
#   <data_integrate.EventGraph at 0x240f9d84910>,
#   <data_integrate.EventGraph at 0x240f9da2f70>,
#   <data_integrate.EventGraph at 0x240f9da8c40>,
#   <data_integrate.EventGraph at 0x240f9dccbb0>,
#   <data_integrate.EventGraph at 0x240f9df1250>,
#   <data_integrate.EventGraph at 0x240f9e1ac40>,
#   <data_integrate.EventGraph at 0x240f9e50970>,
#   <data_integrate.EventGraph at 0x240f9e6efd0>,
#   <data_integrate.EventGraph at 0x240f9e753d0>,
#   <data_integrate.EventGraph at 0x240f9e91a30>,
#   <data_integrate.EventGraph at 0x240f9ebc8e0>,
#   <data_integrate.EventGraph at 0x240f9ef0610>,
#   <data_integrate.EventGraph at 0x240f9f0fc70>,
#   <data_integrate.EventGraph at 0x240f9f38b20>,
#   <data_integrate.EventGraph at 0x240f9f5c670>,
#   <data_integrate.EventGraph at 0x240faf5d460>,
#   <data_integrate.EventGraph at 0x240faf64130>,
#   <data_integrate.EventGraph at 0x240faf64dc0>,
#   <data_integrate.EventGraph at 0x240faf937f0>,
#   <data_integrate.EventGraph at 0x240fafb6760>,
#   <data_integrate.EventGraph at 0x240fafda6d0>,
#   <data_integrate.EventGraph at 0x240fb003580>,
#   <data_integrate.EventGraph at 0x240fb033400>,
#   <data_integrate.EventGraph at 0x240fb0337c0>,
#   <data_integrate.EventGraph at 0x240fb0651f0>,
#   <data_integrate.EventGraph at 0x240fb089160>,
#   <data_integrate.EventGraph at 0x240fb0a67c0>,
#   <data_integrate.EventGraph at 0x240fb0d0670>,
#   <data_integrate.EventGraph at 0x240fb0efcd0>,
#   <data_integrate.EventGraph at 0x240fb113370>,
#   <data_integrate.EventGraph at 0x240fb1309d0>,
#   <data_integrate.EventGraph at 0x240fb155070>,
#   <data_integrate.EventGraph at 0x240fb1746d0>,
#   <data_integrate.EventGraph at 0x240fb196220>,
#   <data_integrate.EventGraph at 0x240fb1b5880>,
#   <data_integrate.EventGraph at 0x240fb1d3ee0>,
#   <data_integrate.EventGraph at 0x240fb1f8580>,
#   <data_integrate.EventGraph at 0x240fb216be0>,
#   <data_integrate.EventGraph at 0x240fb239280>,
#   <data_integrate.EventGraph at 0x240fb26e8e0>,
#   <data_integrate.EventGraph at 0x240fb299790>,
#   <data_integrate.EventGraph at 0x240fb2c81c0>,
#   <data_integrate.EventGraph at 0x240fb2c8e50>,
#   <data_integrate.EventGraph at 0x240fb2cf250>,
#   <data_integrate.EventGraph at 0x240fb2edd60>,
#   <data_integrate.EventGraph at 0x240fb2f5a30>,
#   <data_integrate.EventGraph at 0x240fb3180d0>,
#   <data_integrate.EventGraph at 0x240fb341700>,
#   <data_integrate.EventGraph at 0x240fb3493d0>,
#   <data_integrate.EventGraph at 0x240fb366a30>,
#   <data_integrate.EventGraph at 0x240fb38b580>,
#   <data_integrate.EventGraph at 0x240fb3ae0d0>,
#   <data_integrate.EventGraph at 0x240fb3aed60>,
#   <data_integrate.EventGraph at 0x240fb3d28b0>,
#   <data_integrate.EventGraph at 0x240fb3fc760>,
#   <data_integrate.EventGraph at 0x240fb41bdc0>,
#   <data_integrate.EventGraph at 0x240fb44a7f0>,
#   <data_integrate.EventGraph at 0x240fb47fe50>,
#   <data_integrate.EventGraph at 0x240fb4af880>,
#   <data_integrate.EventGraph at 0x240fb4afc40>,
#   <data_integrate.EventGraph at 0x240fb4d5790>,
#   <data_integrate.EventGraph at 0x240fb4f82e0>,
#   <data_integrate.EventGraph at 0x240fb517940>,
#   <data_integrate.EventGraph at 0x240fb517d00>,
#   <data_integrate.EventGraph at 0x240fb546730>,
#   <data_integrate.EventGraph at 0x240fb564d90>,
#   <data_integrate.EventGraph at 0x240fb56b190>,
#   <data_integrate.EventGraph at 0x240fb5897f0>,
#   <data_integrate.EventGraph at 0x240fb5a6e50>,
#   <data_integrate.EventGraph at 0x240fb5d6880>,
#   <data_integrate.EventGraph at 0x240fb5fa7f0>,
#   <data_integrate.EventGraph at 0x240fb618e50>,
#   <data_integrate.EventGraph at 0x240fb61fb20>,
#   <data_integrate.EventGraph at 0x240fb642670>,
#   <data_integrate.EventGraph at 0x240fb661cd0>,
#   <data_integrate.EventGraph at 0x240fb683820>,
#   <data_integrate.EventGraph at 0x240fb6a3e80>,
#   <data_integrate.EventGraph at 0x240fb6aab50>,
#   <data_integrate.EventGraph at 0x240fb6cc6a0>,
#   <data_integrate.EventGraph at 0x240fb6ebd00>,
#   <data_integrate.EventGraph at 0x240fb70f3a0>,
#   <data_integrate.EventGraph at 0x240fb72deb0>,
#   <data_integrate.EventGraph at 0x240fb757d60>,
#   <data_integrate.EventGraph at 0x240fb77b8b0>,
#   <data_integrate.EventGraph at 0x240fb77bc70>,
#   <data_integrate.EventGraph at 0x240fb7a0310>,
#   <data_integrate.EventGraph at 0x240fb7bf340>,
#   <data_integrate.EventGraph at 0x240fb7dde50>,
#   <data_integrate.EventGraph at 0x240fb8014f0>,
#   <data_integrate.EventGraph at 0x240fb82b3a0>,
#   <data_integrate.EventGraph at 0x240fb832070>,
#   <data_integrate.EventGraph at 0x240fb84e6d0>,
#   <data_integrate.EventGraph at 0x240fb87e550>,
#   <data_integrate.EventGraph at 0x240fb8a30a0>,
#   <data_integrate.EventGraph at 0x240fb8c8f40>,
#   <data_integrate.EventGraph at 0x240fb8eb5b0>,
#   <data_integrate.EventGraph at 0x240fb90f0d0>,
#   <data_integrate.EventGraph at 0x240fb92e760>,
#   <data_integrate.EventGraph at 0x240fb94cdc0>,
#   <data_integrate.EventGraph at 0x240fb97b430>,
#   <data_integrate.EventGraph at 0x240fb99ba90>,
#   <data_integrate.EventGraph at 0x240fb9d5130>,
#   <data_integrate.EventGraph at 0x240fb9d5dc0>,
#   <data_integrate.EventGraph at 0x240fb9fa910>,
#   <data_integrate.EventGraph at 0x240fba18f70>,
#   <data_integrate.EventGraph at 0x240fba20c40>,
#   <data_integrate.EventGraph at 0x240fba43bb0>,
#   <data_integrate.EventGraph at 0x240fba67250>,
#   <data_integrate.EventGraph at 0x240fba67ee0>,
#   <data_integrate.EventGraph at 0x240fba8b580>,
#   <data_integrate.EventGraph at 0x240fba92250>,
#   <data_integrate.EventGraph at 0x240fbaaf8b0>,
#   <data_integrate.EventGraph at 0x240fbacff10>,
#   <data_integrate.EventGraph at 0x240fbaf15b0>,
#   <data_integrate.EventGraph at 0x240fbb16100>,
#   <data_integrate.EventGraph at 0x240fbb164c0>,
#   <data_integrate.EventGraph at 0x240fbb472b0>,
#   <data_integrate.EventGraph at 0x240fbb65dc0>,
#   <data_integrate.EventGraph at 0x240fbb88d30>,
#   <data_integrate.EventGraph at 0x240fbbad3d0>,
#   <data_integrate.EventGraph at 0x240fbbcaa30>,
#   <data_integrate.EventGraph at 0x240fbbef0d0>,
#   <data_integrate.EventGraph at 0x240fbc15040>,
#   <data_integrate.EventGraph at 0x240fbc15cd0>,
#   <data_integrate.EventGraph at 0x240fbc37370>,
#   <data_integrate.EventGraph at 0x240fbc5b2e0>,
#   <data_integrate.EventGraph at 0x240fbc5bf70>,
#   <data_integrate.EventGraph at 0x240fbc80610>,
#   <data_integrate.EventGraph at 0x240f9110040>,
#   <data_integrate.EventGraph at 0x240f912df70>,
#   <data_integrate.EventGraph at 0x240f9152610>,
#   <data_integrate.EventGraph at 0x240f9175580>,
#   <data_integrate.EventGraph at 0x240f9175940>,
#   <data_integrate.EventGraph at 0x240f917d610>,
#   <data_integrate.EventGraph at 0x240f919f160>,
#   <data_integrate.EventGraph at 0x240f91c30d0>,
#   <data_integrate.EventGraph at 0x240f91eeac0>,
#   <data_integrate.EventGraph at 0x240f91f3790>,
#   <data_integrate.EventGraph at 0x240f9217700>,
#   <data_integrate.EventGraph at 0x240f9248130>,
#   <data_integrate.EventGraph at 0x240f9248dc0>,
#   <data_integrate.EventGraph at 0x240f92501c0>,
#   <data_integrate.EventGraph at 0x240f926dcd0>,
#   <data_integrate.EventGraph at 0x240f9291820>,
#   <data_integrate.EventGraph at 0x240f92aee80>,
#   <data_integrate.EventGraph at 0x240f92ddc70>,
#   <data_integrate.EventGraph at 0x240f9301310>,
#   <data_integrate.EventGraph at 0x240f931fe20>,
#   <data_integrate.EventGraph at 0x240f9344970>,
#   <data_integrate.EventGraph at 0x240f93743a0>,
#   <data_integrate.EventGraph at 0x240f9391a00>,
#   <data_integrate.EventGraph at 0x240f93c3070>,
#   <data_integrate.EventGraph at 0x240f93f3700>,
#   <data_integrate.EventGraph at 0x240f9422130>,
#   <data_integrate.EventGraph at 0x240f9422dc0>,
#   <data_integrate.EventGraph at 0x240f942aa90>,
#   <data_integrate.EventGraph at 0x240f944d130>,
#   <data_integrate.EventGraph at 0x240f9477b20>,
#   <data_integrate.EventGraph at 0x240f947e7f0>,
#   <data_integrate.EventGraph at 0x240f949be50>,
#   <data_integrate.EventGraph at 0x240f94ca880>,
#   <data_integrate.EventGraph at 0x240f94d1550>,
#   <data_integrate.EventGraph at 0x240f94f64c0>,
#   <data_integrate.EventGraph at 0x240f951feb0>,
#   <data_integrate.EventGraph at 0x240f9541a00>,
#   <data_integrate.EventGraph at 0x240f9567550>,
#   <data_integrate.EventGraph at 0x240f956e220>,
#   <data_integrate.EventGraph at 0x240f9597c10>,
#   <data_integrate.EventGraph at 0x240f95b5c40>,
#   <data_integrate.EventGraph at 0x240f95d8bb0>,
#   <data_integrate.EventGraph at 0x240f95e0880>,
#   <data_integrate.EventGraph at 0x240f95e6550>,
#   <data_integrate.EventGraph at 0x240f960e400>,
#   <data_integrate.EventGraph at 0x240f962da60>,
#   <data_integrate.EventGraph at 0x240f9634730>,
#   <data_integrate.EventGraph at 0x240f9653d90>,
#   <data_integrate.EventGraph at 0x240f9671dc0>,
#   <data_integrate.EventGraph at 0x240f9694d30>,
#   <data_integrate.EventGraph at 0x240f96b8880>,
#   <data_integrate.EventGraph at 0x240f96e82b0>,
#   <data_integrate.EventGraph at 0x240f9706dc0>,
#   <data_integrate.EventGraph at 0x240f970da90>,
#   <data_integrate.EventGraph at 0x240f9735940>,
#   <data_integrate.EventGraph at 0x240f9765370>,
#   <data_integrate.EventGraph at 0x240f97892e0>,
#   <data_integrate.EventGraph at 0x240f97896a0>,
#   <data_integrate.EventGraph at 0x240f97ae1f0>,
#   <data_integrate.EventGraph at 0x240f97d1160>,
#   <data_integrate.EventGraph at 0x240f97f07c0>,
#   <data_integrate.EventGraph at 0x240f980ee20>,
#   <data_integrate.EventGraph at 0x240f98329a0>,
#   <data_integrate.EventGraph at 0x240f9861760>,
#   <data_integrate.EventGraph at 0x240f9891190>,
#   <data_integrate.EventGraph at 0x240f98b0ca0>,
#   <data_integrate.EventGraph at 0x240f98dea90>,
#   <data_integrate.EventGraph at 0x240f9902a00>,
#   <data_integrate.EventGraph at 0x240f99260a0>,
#   <data_integrate.EventGraph at 0x240f9943700>,
#   <data_integrate.EventGraph at 0x240f9943ac0>,
#   <data_integrate.EventGraph at 0x240f994d790>,
#   <data_integrate.EventGraph at 0x240f996f2e0>,
#   <data_integrate.EventGraph at 0x240f9998cd0>,
#   <data_integrate.EventGraph at 0x240f99be370>,
#   <data_integrate.EventGraph at 0x240f99c5040>,
#   <data_integrate.EventGraph at 0x240f99e06a0>,
#   <data_integrate.EventGraph at 0x240f99ffd00>,
#   <data_integrate.EventGraph at 0x240f9a07100>,
#   <data_integrate.EventGraph at 0x240f9a2faf0>,
#   <data_integrate.EventGraph at 0x240f9a5f520>,
#   <data_integrate.EventGraph at 0x240f9a7cb80>,
#   <data_integrate.EventGraph at 0x240f9aa0220>,
#   <data_integrate.EventGraph at 0x240f9abe880>,
#   <data_integrate.EventGraph at 0x240f9abec40>,
#   <data_integrate.EventGraph at 0x240f9aeaaf0>,
#   <data_integrate.EventGraph at 0x240f9b0e190>,
#   <data_integrate.EventGraph at 0x240fd0dcca0>,
#   <data_integrate.EventGraph at 0x240fd100340>,
#   <data_integrate.EventGraph at 0x240fd11d370>,
#   <data_integrate.EventGraph at 0x240fd13c9d0>,
#   <data_integrate.EventGraph at 0x240fd178070>,
#   <data_integrate.EventGraph at 0x240fd178d00>,
#   <data_integrate.EventGraph at 0x240fd19c3a0>,
#   <data_integrate.EventGraph at 0x240fd1c6d90>,
#   <data_integrate.EventGraph at 0x240fd1e9430>,
#   <data_integrate.EventGraph at 0x240fd1e97f0>,
#   <data_integrate.EventGraph at 0x240fd219e80>,
#   <data_integrate.EventGraph at 0x240fd23edf0>,
#   <data_integrate.EventGraph at 0x240fd26d820>,
#   <data_integrate.EventGraph at 0x240fd28be80>,
#   <data_integrate.EventGraph at 0x240fd2bb8b0>,
#   <data_integrate.EventGraph at 0x240fd2f0f10>,
#   <data_integrate.EventGraph at 0x240fd3155b0>,
#   <data_integrate.EventGraph at 0x240fd333c10>,
#   <data_integrate.EventGraph at 0x240fd333fd0>,
#   <data_integrate.EventGraph at 0x240fd356670>,
#   <data_integrate.EventGraph at 0x240fd374cd0>,
#   <data_integrate.EventGraph at 0x240fd3b0ca0>,
#   <data_integrate.EventGraph at 0x240fd3d37f0>,
#   <data_integrate.EventGraph at 0x240fd3f8340>,
#   <data_integrate.EventGraph at 0x240fd422d30>,
#   <data_integrate.EventGraph at 0x240fd451760>,
#   <data_integrate.EventGraph at 0x240fd4742b0>,
#   <data_integrate.EventGraph at 0x240fd498220>,
#   <data_integrate.EventGraph at 0x240fd4bd190>,
#   <data_integrate.EventGraph at 0x240fd4e0100>,
#   <data_integrate.EventGraph at 0x240fd4e0d90>,
#   <data_integrate.EventGraph at 0x240fd510b80>,
#   <data_integrate.EventGraph at 0x240fd536220>,
#   <data_integrate.EventGraph at 0x240fd554d30>,
#   <data_integrate.EventGraph at 0x240fd583bb0>,
#   <data_integrate.EventGraph at 0x240fd5b45e0>,
#   <data_integrate.EventGraph at 0x240fd5e3c70>,
#   <data_integrate.EventGraph at 0x240fd608310>,
#   <data_integrate.EventGraph at 0x240fd63e040>,
#   <data_integrate.EventGraph at 0x240fd63e400>,
#   <data_integrate.EventGraph at 0x240fd6440d0>,
#   <data_integrate.EventGraph at 0x240fd662be0>,
#   <data_integrate.EventGraph at 0x240fd692610>,
#   <data_integrate.EventGraph at 0x240fd6b5160>],
#  '2022-08-23 17:00': [<data_integrate.EventGraph at 0x240fd6d3760>,
#   <data_integrate.EventGraph at 0x240fd6f1e20>,
#   <data_integrate.EventGraph at 0x240fd720850>,
#   <data_integrate.EventGraph at 0x240fd750280>,
#   <data_integrate.EventGraph at 0x240fd76e8e0>,
#   <data_integrate.EventGraph at 0x240fd78df40>,
#   <data_integrate.EventGraph at 0x240fd7b2a90>,
#   <data_integrate.EventGraph at 0x240fd7d5130>,
#   <data_integrate.EventGraph at 0x240fd7f4790>,
#   <data_integrate.EventGraph at 0x240fd817700>,
#   <data_integrate.EventGraph at 0x240fd835d60>,
#   <data_integrate.EventGraph at 0x240fd8598b0>,
#   <data_integrate.EventGraph at 0x240fd87c430>,
#   <data_integrate.EventGraph at 0x240c5de3430>,
#   <data_integrate.EventGraph at 0x240fd8b9ee0>,
#   <data_integrate.EventGraph at 0x240fd8de580>,
#   <data_integrate.EventGraph at 0x240fd8fcbe0>,
#   <data_integrate.EventGraph at 0x240fd92b610>,
#   <data_integrate.EventGraph at 0x240fd949c70>,
#   <data_integrate.EventGraph at 0x240fd950940>,
#   <data_integrate.EventGraph at 0x240fd973490>,
#   <data_integrate.EventGraph at 0x240fd998400>,
#   <data_integrate.EventGraph at 0x240fd9987c0>,
#   <data_integrate.EventGraph at 0x240fd9c75b0>,
#   <data_integrate.EventGraph at 0x240fd9eb100>,
#   <data_integrate.EventGraph at 0x240fda09760>,
#   <data_integrate.EventGraph at 0x240fda28dc0>,
#   <data_integrate.EventGraph at 0x240fda577f0>,
#   <data_integrate.EventGraph at 0x240fda76e50>,
#   <data_integrate.EventGraph at 0x240fda7d250>,
#   <data_integrate.EventGraph at 0x240fda9a8b0>,
#   <data_integrate.EventGraph at 0x240fdab98e0>,
#   <data_integrate.EventGraph at 0x240fdab9ca0>,
#   <data_integrate.EventGraph at 0x240fdae8a90>,
#   <data_integrate.EventGraph at 0x240fdb0da00>,
#   <data_integrate.EventGraph at 0x240fdb300a0>,
#   <data_integrate.EventGraph at 0x240fdb4ebb0>,
#   <data_integrate.EventGraph at 0x240fdb73250>,
#   <data_integrate.EventGraph at 0x240fdb918b0>,
#   <data_integrate.EventGraph at 0x240fdbaef10>,
#   <data_integrate.EventGraph at 0x240fdbd35b0>,
#   <data_integrate.EventGraph at 0x240fdbfcfa0>,
#   <data_integrate.EventGraph at 0x240fdc21640>,
#   <data_integrate.EventGraph at 0x240fdc44190>,
#   <data_integrate.EventGraph at 0x240fdc6df40>,
#   <data_integrate.EventGraph at 0x240fdc915e0>,
#   <data_integrate.EventGraph at 0x240fdcb0c40>,
#   <data_integrate.EventGraph at 0x240fdceb370>,
#   <data_integrate.EventGraph at 0x240fdd0be80>,
#   <data_integrate.EventGraph at 0x240fdd34d30>,
#   <data_integrate.EventGraph at 0x240fdd58ca0>,
#   <data_integrate.EventGraph at 0x240fdd7d340>,
#   <data_integrate.EventGraph at 0x240fdda12b0>,
#   <data_integrate.EventGraph at 0x240fddd5190>,
#   <data_integrate.EventGraph at 0x240fddfb100>,
#   <data_integrate.EventGraph at 0x240fde1ac10>,
#   <data_integrate.EventGraph at 0x240fde48640>,
#   <data_integrate.EventGraph at 0x240fde78070>,
#   <data_integrate.EventGraph at 0x240fde96b80>,
#   <data_integrate.EventGraph at 0x240fdec55b0>,
#   <data_integrate.EventGraph at 0x240fdecc280>,
#   <data_integrate.EventGraph at 0x240fdef6c70>,
#   <data_integrate.EventGraph at 0x240fdf18be0>,
#   <data_integrate.EventGraph at 0x240fdf3d280>,
#   <data_integrate.EventGraph at 0x240fdf5b2b0>,
#   <data_integrate.EventGraph at 0x240fdf8f910>,
#   <data_integrate.EventGraph at 0x240fdfb5880>,
#   <data_integrate.EventGraph at 0x240fdfd2ee0>,
#   <data_integrate.EventGraph at 0x240fdff6e50>,
#   <data_integrate.EventGraph at 0x240fe01b9a0>,
#   <data_integrate.EventGraph at 0x240fe040040>,
#   <data_integrate.EventGraph at 0x240fe063eb0>,
#   <data_integrate.EventGraph at 0x240fe069b80>,
#   <data_integrate.EventGraph at 0x240fe08b220>,
#   <data_integrate.EventGraph at 0x240fe0b60d0>,
#   <data_integrate.EventGraph at 0x240fe0d4be0>,
#   <data_integrate.EventGraph at 0x240fe0f8280>,
#   <data_integrate.EventGraph at 0x240fe0f8640>,
#   <data_integrate.EventGraph at 0x240fe119ca0>,
#   <data_integrate.EventGraph at 0x240fe13d340>,
#   <data_integrate.EventGraph at 0x240fe166d30>,
#   <data_integrate.EventGraph at 0x240fe194bb0>,
#   <data_integrate.EventGraph at 0x240fe1ba250>,
#   <data_integrate.EventGraph at 0x240fe1e4880>,
#   <data_integrate.EventGraph at 0x240fe202ee0>,
#   <data_integrate.EventGraph at 0x240fe238dc0>,
#   <data_integrate.EventGraph at 0x240fe25ed30>,
#   <data_integrate.EventGraph at 0x240fe28e760>,
#   <data_integrate.EventGraph at 0x240fe2bd190>,
#   <data_integrate.EventGraph at 0x240fe2db7f0>,
#   <data_integrate.EventGraph at 0x240fe2f7e50>,
#   <data_integrate.EventGraph at 0x240fe32db80>,
#   <data_integrate.EventGraph at 0x240fe351220>,
#   <data_integrate.EventGraph at 0x240fe370d30>,
#   <data_integrate.EventGraph at 0x240fe3a0760>,
#   <data_integrate.EventGraph at 0x240fe3bd790>,
#   <data_integrate.EventGraph at 0x240fe3ed1c0>,
#   <data_integrate.EventGraph at 0x240fe40a820>,
#   <data_integrate.EventGraph at 0x240fe42f370>,
#   <data_integrate.EventGraph at 0x240fe45e160>,
#   <data_integrate.EventGraph at 0x240fe47c7c0>,
#   <data_integrate.EventGraph at 0x240fe4a0310>,
#   <data_integrate.EventGraph at 0x240fe4bf340>,
#   <data_integrate.EventGraph at 0x240fe4bf700>,
#   <data_integrate.EventGraph at 0x240fe4ddd60>,
#   <data_integrate.EventGraph at 0x240fe5018b0>,
#   <data_integrate.EventGraph at 0x240fe51ff10>,
#   <data_integrate.EventGraph at 0x240fe526310>,
#   <data_integrate.EventGraph at 0x240fe5266d0>,
#   <data_integrate.EventGraph at 0x240fe55b400>,
#   <data_integrate.EventGraph at 0x240fe579a60>,
#   <data_integrate.EventGraph at 0x240fe5a80d0>,
#   <data_integrate.EventGraph at 0x240fe5a8490>,
#   <data_integrate.EventGraph at 0x240fe5c9fa0>,
#   <data_integrate.EventGraph at 0x240fe5fa9d0>,
#   <data_integrate.EventGraph at 0x240fe61e070>,
#   <data_integrate.EventGraph at 0x240fe61e430>,
#   <data_integrate.EventGraph at 0x240fe63ba90>,
#   <data_integrate.EventGraph at 0x240fe65f130>,
#   <data_integrate.EventGraph at 0x240fe67e790>,
#   <data_integrate.EventGraph at 0x240fe684460>,
#   <data_integrate.EventGraph at 0x240fe6a1ac0>,
#   <data_integrate.EventGraph at 0x240fe6d77f0>,
#   <data_integrate.EventGraph at 0x240fe6d7bb0>,
#   <data_integrate.EventGraph at 0x240fe6fc250>,
#   <data_integrate.EventGraph at 0x240fe726100>,
#   <data_integrate.EventGraph at 0x240fe743760>,
#   <data_integrate.EventGraph at 0x240fe74a400>,
#   <data_integrate.EventGraph at 0x240fe752100>,
#   <data_integrate.EventGraph at 0x240fe76e760>,
#   <data_integrate.EventGraph at 0x240fe78cdc0>,
#   <data_integrate.EventGraph at 0x240fe794a90>,
#   <data_integrate.EventGraph at 0x240fe7b75e0>,
#   <data_integrate.EventGraph at 0x240fe7edcd0>,
#   <data_integrate.EventGraph at 0x240fe811370>,
#   <data_integrate.EventGraph at 0x240fe8421f0>,
#   <data_integrate.EventGraph at 0x240fe860850>,
#   <data_integrate.EventGraph at 0x240fe867520>,
#   <data_integrate.EventGraph at 0x240fe89d250>,
#   <data_integrate.EventGraph at 0x240fe8c6c40>,
#   <data_integrate.EventGraph at 0x240fe8e82e0>,
#   <data_integrate.EventGraph at 0x240fe8e8f70>,
#   <data_integrate.EventGraph at 0x240fe90e610>,
#   <data_integrate.EventGraph at 0x240fe90e9d0>,
#   <data_integrate.EventGraph at 0x240fe932070>,
#   <data_integrate.EventGraph at 0x240fe932d00>,
#   <data_integrate.EventGraph at 0x240fe9583a0>,
#   <data_integrate.EventGraph at 0x240fe982d90>,
#   <data_integrate.EventGraph at 0x240fe9abc40>,
#   <data_integrate.EventGraph at 0x240fe9cd2e0>,
#   <data_integrate.EventGraph at 0x240fe9eddf0>,
#   <data_integrate.EventGraph at 0x240fe9f3ac0>,
#   <data_integrate.EventGraph at 0x240fea18160>,
#   <data_integrate.EventGraph at 0x240fea42b50>,
#   <data_integrate.EventGraph at 0x240fea7c1f0>,
#   <data_integrate.EventGraph at 0x240fea7ce80>,
#   <data_integrate.EventGraph at 0x240feaa0520>,
#   <data_integrate.EventGraph at 0x240feabeb80>,
#   <data_integrate.EventGraph at 0x240feabef40>,
#   <data_integrate.EventGraph at 0x240feaee970>,
#   <data_integrate.EventGraph at 0x240feb0d9a0>,
#   <data_integrate.EventGraph at 0x240feb30040>,
#   <data_integrate.EventGraph at 0x240feb30400>,
#   <data_integrate.EventGraph at 0x240feb4fa60>,
#   <data_integrate.EventGraph at 0x240feb7f490>,
#   <data_integrate.EventGraph at 0x240feb7f850>,
#   <data_integrate.EventGraph at 0x240feb9d880>,
#   <data_integrate.EventGraph at 0x240febbb8b0>,
#   <data_integrate.EventGraph at 0x240febe6760>,
#   <data_integrate.EventGraph at 0x240fec10d90>,
#   <data_integrate.EventGraph at 0x240fec3bc40>,
#   <data_integrate.EventGraph at 0x240fec58c70>,
#   <data_integrate.EventGraph at 0x240fec60070>,
#   <data_integrate.EventGraph at 0x240fec88a60>,
#   <data_integrate.EventGraph at 0x240fecad9d0>,
#   <data_integrate.EventGraph at 0x240fecd0520>,
#   <data_integrate.EventGraph at 0x240fecf4490>,
#   <data_integrate.EventGraph at 0x240fecfd160>,
#   <data_integrate.EventGraph at 0x240fed197c0>,
#   <data_integrate.EventGraph at 0x240fed20490>,
#   <data_integrate.EventGraph at 0x240fed3eaf0>,
#   <data_integrate.EventGraph at 0x240fed6d160>,
#   <data_integrate.EventGraph at 0x240fed920d0>,
#   <data_integrate.EventGraph at 0x240fed92d60>,
#   <data_integrate.EventGraph at 0x240fed99a30>,
#   <data_integrate.EventGraph at 0x240fedbc0d0>,
#   <data_integrate.EventGraph at 0x240feddcbe0>,
#   <data_integrate.EventGraph at 0x240fede48b0>,
#   <data_integrate.EventGraph at 0x240fee01f10>,
#   <data_integrate.EventGraph at 0x240fee255b0>,
#   <data_integrate.EventGraph at 0x240fee2c280>,
#   <data_integrate.EventGraph at 0x240fee488e0>,
#   <data_integrate.EventGraph at 0x240fee66910>,
#   <data_integrate.EventGraph at 0x240fee96700>,
#   <data_integrate.EventGraph at 0x240feeb5d60>,
#   <data_integrate.EventGraph at 0x240feeda8b0>,
#   <data_integrate.EventGraph at 0x240feefd820>,
#   <data_integrate.EventGraph at 0x240fef266d0>,
#   <data_integrate.EventGraph at 0x240fef4b640>,
#   <data_integrate.EventGraph at 0x240fef6d190>,
#   <data_integrate.EventGraph at 0x240fef92100>,
#   <data_integrate.EventGraph at 0x240fef92d90>,
#   <data_integrate.EventGraph at 0x240fefb78e0>,
#   <data_integrate.EventGraph at 0x240fefbe5b0>,
#   <data_integrate.EventGraph at 0x240feff32e0>,
#   <data_integrate.EventGraph at 0x240ff010940>,
#   <data_integrate.EventGraph at 0x240ff03b7f0>,
#   <data_integrate.EventGraph at 0x240ff058e50>,
#   <data_integrate.EventGraph at 0x240ff07d4f0>,
#   <data_integrate.EventGraph at 0x240ff0a6ee0>,
#   <data_integrate.EventGraph at 0x240ff0d5d60>,
#   <data_integrate.EventGraph at 0x240ff0fa400>,
#   <data_integrate.EventGraph at 0x240ff118a60>,
#   <data_integrate.EventGraph at 0x240ff118e20>,
#   <data_integrate.EventGraph at 0x240ff13e970>,
#   <data_integrate.EventGraph at 0x240ff13ed30>,
#   <data_integrate.EventGraph at 0x240ff1623d0>,
#   <data_integrate.EventGraph at 0x240ff181ee0>,
#   <data_integrate.EventGraph at 0x240ff1a4580>,
#   <data_integrate.EventGraph at 0x240ff1dabe0>,
#   <data_integrate.EventGraph at 0x240ff1fd280>,
#   <data_integrate.EventGraph at 0x240ff1fd640>,
#   <data_integrate.EventGraph at 0x240ff21dca0>,
#   <data_integrate.EventGraph at 0x240ff224970>,
#   <data_integrate.EventGraph at 0x240ff2474c0>,
#   <data_integrate.EventGraph at 0x240ff265fd0>,
#   <data_integrate.EventGraph at 0x240ff289670>,
#   <data_integrate.EventGraph at 0x240ff2a6cd0>,
#   <data_integrate.EventGraph at 0x240ff2cb820>,
#   <data_integrate.EventGraph at 0x240ff2d24f0>,
#   <data_integrate.EventGraph at 0x240ff2fb3a0>,
#   <data_integrate.EventGraph at 0x240ff320310>,
#   <data_integrate.EventGraph at 0x240ff33d970>,
#   <data_integrate.EventGraph at 0x240ff35bfd0>,
#   <data_integrate.EventGraph at 0x240ff380670>,
#   <data_integrate.EventGraph at 0x240ff387340>,
#   <data_integrate.EventGraph at 0x240ff3a49a0>,
#   <data_integrate.EventGraph at 0x240ff3d33d0>,
#   <data_integrate.EventGraph at 0x240ff4021c0>,
#   <data_integrate.EventGraph at 0x240ff42e070>,
#   <data_integrate.EventGraph at 0x240ff457a60>,
#   <data_integrate.EventGraph at 0x240ff457e20>,
#   <data_integrate.EventGraph at 0x240ff47b4c0>,
#   <data_integrate.EventGraph at 0x240ff499b20>,
#   <data_integrate.EventGraph at 0x240ff4bd1c0>,
#   <data_integrate.EventGraph at 0x240fbce28b0>,
#   <data_integrate.EventGraph at 0x240fbd00f10>,
#   <data_integrate.EventGraph at 0x240fbd08310>,
#   <data_integrate.EventGraph at 0x240fbd301c0>,
#   <data_integrate.EventGraph at 0x240fbd50820>,
#   <data_integrate.EventGraph at 0x240fbd6ee80>,
#   <data_integrate.EventGraph at 0x240fbd9d8b0>,
#   <data_integrate.EventGraph at 0x240fbdbcf10>,
#   <data_integrate.EventGraph at 0x240fbddf5b0>,
#   <data_integrate.EventGraph at 0x240fbe03100>,
#   <data_integrate.EventGraph at 0x240fbe38760>,
#   <data_integrate.EventGraph at 0x240fbe40430>,
#   <data_integrate.EventGraph at 0x240fbe5ca90>,
#   <data_integrate.EventGraph at 0x240fbe81130>,
#   <data_integrate.EventGraph at 0x240fbe814f0>,
#   <data_integrate.EventGraph at 0x240fbe9fb50>,
#   <data_integrate.EventGraph at 0x240fbebdb80>,
#   <data_integrate.EventGraph at 0x240fbec5850>,
#   <data_integrate.EventGraph at 0x240fbee87c0>,
#   <data_integrate.EventGraph at 0x240fbf1ee20>,
#   <data_integrate.EventGraph at 0x240fbf25af0>,
#   <data_integrate.EventGraph at 0x240fbf48190>,
#   <data_integrate.EventGraph at 0x240fbf66ca0>,
#   <data_integrate.EventGraph at 0x240fbf8b7f0>,
#   <data_integrate.EventGraph at 0x240fbfae310>,
#   <data_integrate.EventGraph at 0x240fbfe41f0>,
#   <data_integrate.EventGraph at 0x240fc002850>,
#   <data_integrate.EventGraph at 0x240fc002c10>,
#   <data_integrate.EventGraph at 0x240fc032640>,
#   <data_integrate.EventGraph at 0x240fc032a00>,
#   <data_integrate.EventGraph at 0x240fc0570a0>,
#   <data_integrate.EventGraph at 0x240fc075bb0>,
#   <data_integrate.EventGraph at 0x240fc099b20>,
#   <data_integrate.EventGraph at 0x240fc099ee0>,
#   <data_integrate.EventGraph at 0x240fc0a1bb0>,
#   <data_integrate.EventGraph at 0x240fc0c4250>,
#   <data_integrate.EventGraph at 0x240fc0e2d60>,
#   <data_integrate.EventGraph at 0x240fc112790>,
#   <data_integrate.EventGraph at 0x240fc1362e0>,
#   <data_integrate.EventGraph at 0x240fc1366a0>,
#   <data_integrate.EventGraph at 0x240fc160550>,
#   <data_integrate.EventGraph at 0x240fc168220>,
#   <data_integrate.EventGraph at 0x240fc184250>,
#   <data_integrate.EventGraph at 0x240fc184ee0>,
#   <data_integrate.EventGraph at 0x240fc1a9580>,
#   <data_integrate.EventGraph at 0x240fc1cd0d0>,
#   <data_integrate.EventGraph at 0x240fc1cdd60>,
#   <data_integrate.EventGraph at 0x240fc1f1cd0>,
#   <data_integrate.EventGraph at 0x240fc1f80d0>,
#   <data_integrate.EventGraph at 0x240fc217730>,
#   <data_integrate.EventGraph at 0x240fc235d90>,
#   <data_integrate.EventGraph at 0x240fc259430>,
#   <data_integrate.EventGraph at 0x240fc277a90>,
#   <data_integrate.EventGraph at 0x240fc29b130>,
#   <data_integrate.EventGraph at 0x240fc2b9790>,
#   <data_integrate.EventGraph at 0x240fc2d8df0>,
#   <data_integrate.EventGraph at 0x240fc2fb490>,
#   <data_integrate.EventGraph at 0x240fc303160>,
#   <data_integrate.EventGraph at 0x240fc303df0>,
#   <data_integrate.EventGraph at 0x240fc327490>,
#   <data_integrate.EventGraph at 0x240fc345af0>,
#   <data_integrate.EventGraph at 0x240fc34b7c0>,
#   <data_integrate.EventGraph at 0x240fc3697f0>,
#   <data_integrate.EventGraph at 0x240fc398220>,
#   <data_integrate.EventGraph at 0x240fc3b6880>,
#   <data_integrate.EventGraph at 0x240fc3db3d0>,
#   <data_integrate.EventGraph at 0x240fc3f9a30>,
#   <data_integrate.EventGraph at 0x240fc41d0d0>,
#   <data_integrate.EventGraph at 0x240fc41d490>,
#   <data_integrate.EventGraph at 0x240fc44c280>,
#   <data_integrate.EventGraph at 0x240fc476130>,
#   <data_integrate.EventGraph at 0x240fc49fb20>,
#   <data_integrate.EventGraph at 0x240fc4c3670>,
#   <data_integrate.EventGraph at 0x240fc4c3a30>,
#   <data_integrate.EventGraph at 0x240fc4e8580>,
#   <data_integrate.EventGraph at 0x240fc512f70>,
#   <data_integrate.EventGraph at 0x240fc537ee0>,
#   <data_integrate.EventGraph at 0x240fc566910>,
#   <data_integrate.EventGraph at 0x240fc583f70>,
#   <data_integrate.EventGraph at 0x240fc5a7610>,
#   <data_integrate.EventGraph at 0x240fc5c6c70>,
#   <data_integrate.EventGraph at 0x240fc5ce070>,
#   <data_integrate.EventGraph at 0x240fc5eb6d0>,
#   <data_integrate.EventGraph at 0x240fc614580>,
#   <data_integrate.EventGraph at 0x240fc632be0>,
#   <data_integrate.EventGraph at 0x240fc656b50>,
#   <data_integrate.EventGraph at 0x240fc685940>,
#   <data_integrate.EventGraph at 0x240fc6aa490>,
#   <data_integrate.EventGraph at 0x240fc6c8af0>,
#   <data_integrate.EventGraph at 0x240fc6ec640>,
#   <data_integrate.EventGraph at 0x240fc6f3310>,
#   <data_integrate.EventGraph at 0x240fc6f3fa0>,
#   <data_integrate.EventGraph at 0x240fc727cd0>,
#   <data_integrate.EventGraph at 0x240fc74a370>,
#   <data_integrate.EventGraph at 0x240fc77c160>,
#   <data_integrate.EventGraph at 0x240fc77cdf0>,
#   <data_integrate.EventGraph at 0x240fc79f490>,
#   <data_integrate.EventGraph at 0x240fc7beaf0>,
#   <data_integrate.EventGraph at 0x240fc7e1640>,
#   <data_integrate.EventGraph at 0x240fc7e1a00>,
#   <data_integrate.EventGraph at 0x240fc7ea6d0>,
#   <data_integrate.EventGraph at 0x240fc7f13a0>,
#   <data_integrate.EventGraph at 0x240fc819d90>,
#   <data_integrate.EventGraph at 0x240fc854430>,
#   <data_integrate.EventGraph at 0x240fc873a90>,
#   <data_integrate.EventGraph at 0x240fc896130>,
#   <data_integrate.EventGraph at 0x240fc8b5790>,
#   <data_integrate.EventGraph at 0x240fc8b5b50>,
#   <data_integrate.EventGraph at 0x240fc8d86a0>,
#   <data_integrate.EventGraph at 0x240fc8fc1f0>,
#   <data_integrate.EventGraph at 0x240fc926be0>,
#   <data_integrate.EventGraph at 0x240fc9559d0>,
#   <data_integrate.EventGraph at 0x240fc97b070>,
#   <data_integrate.EventGraph at 0x240fc998fa0>,
#   <data_integrate.EventGraph at 0x240fc9bc640>,
#   <data_integrate.EventGraph at 0x240fc9daca0>,
#   <data_integrate.EventGraph at 0x240fca096d0>,
#   <data_integrate.EventGraph at 0x240fca27d30>,
#   <data_integrate.EventGraph at 0x240fca4a3d0>,
#   <data_integrate.EventGraph at 0x240fca75dc0>,
#   <data_integrate.EventGraph at 0x240fca98460>,
#   <data_integrate.EventGraph at 0x240fcab8ac0>,
#   <data_integrate.EventGraph at 0x240fcadba30>,
#   <data_integrate.EventGraph at 0x240fcaff580>,
#   <data_integrate.EventGraph at 0x240fcb230d0>,
#   <data_integrate.EventGraph at 0x240fcb4dac0>,
#   <data_integrate.EventGraph at 0x240fcb70160>,
#   <data_integrate.EventGraph at 0x240fcb9ab50>,
#   <data_integrate.EventGraph at 0x240fcbbe1f0>,
#   <data_integrate.EventGraph at 0x240fcbe1160>,
#   <data_integrate.EventGraph at 0x240fcc017c0>,
#   <data_integrate.EventGraph at 0x240fcc2adf0>,
#   <data_integrate.EventGraph at 0x240fcc4f490>,
#   <data_integrate.EventGraph at 0x240fcc79340>,
#   <data_integrate.EventGraph at 0x240fcca2d30>,
#   <data_integrate.EventGraph at 0x240fcca9a00>,
#   <data_integrate.EventGraph at 0x240fccae6d0>,
#   <data_integrate.EventGraph at 0x240fcccdd30>,
#   <data_integrate.EventGraph at 0x240fccf13d0>,
#   <data_integrate.EventGraph at 0x240fcd10ee0>,
#   <data_integrate.EventGraph at 0x240fcd40550>,
#   <data_integrate.EventGraph at 0x240fcd650a0>,
#   <data_integrate.EventGraph at 0x240fcd8eee0>,
#   <data_integrate.EventGraph at 0x240fcdb2580>,
#   <data_integrate.EventGraph at 0x240fcdd84f0>,
#   <data_integrate.EventGraph at 0x240fcdfd040>,
#   <data_integrate.EventGraph at 0x240fce19b50>,
#   <data_integrate.EventGraph at 0x240fce36b80>,
#   <data_integrate.EventGraph at 0x240fce36f40>,
#   <data_integrate.EventGraph at 0x240fce5d5e0>,
#   <data_integrate.EventGraph at 0x240fce80130>,
#   <data_integrate.EventGraph at 0x240fce9ec40>,
#   <data_integrate.EventGraph at 0x240fcec3790>,
#   <data_integrate.EventGraph at 0x240fcee1df0>,
#   <data_integrate.EventGraph at 0x240fcf04940>,
#   <data_integrate.EventGraph at 0x240fcf288b0>,
#   <data_integrate.EventGraph at 0x240fcf28c70>,
#   <data_integrate.EventGraph at 0x240fcf4d310>,
#   <data_integrate.EventGraph at 0x240fcf6be20>,
#   <data_integrate.EventGraph at 0x240fcf8f970>,
#   <data_integrate.EventGraph at 0x240fcfbf3a0>,
#   <data_integrate.EventGraph at 0x240fcfe2310>,
#   <data_integrate.EventGraph at 0x240fd011100>,
#   <data_integrate.EventGraph at 0x240fd03c730>,
#   <data_integrate.EventGraph at 0x240fd05b760>,
#   <data_integrate.EventGraph at 0x240fd079dc0>,
#   <data_integrate.EventGraph at 0x240fd09d430>,
#   <data_integrate.EventGraph at 0x240ff4cbf70>,
#   <data_integrate.EventGraph at 0x240ff4f05e0>,
#   <data_integrate.EventGraph at 0x240ff513580>,
#   <data_integrate.EventGraph at 0x240ff53d430>,
#   <data_integrate.EventGraph at 0x240ff5672e0>,
#   <data_integrate.EventGraph at 0x240ff584940>,
#   <data_integrate.EventGraph at 0x240ff5a2fa0>,
#   <data_integrate.EventGraph at 0x240ff5c6640>,
#   <data_integrate.EventGraph at 0x240ff5ce310>,
#   <data_integrate.EventGraph at 0x240ff5ece20>,
#   <data_integrate.EventGraph at 0x240ff61c850>,
#   <data_integrate.EventGraph at 0x240ff622520>,
#   <data_integrate.EventGraph at 0x240ff63fb80>,
#   <data_integrate.EventGraph at 0x240ff647850>,
#   <data_integrate.EventGraph at 0x240ff664880>,
#   <data_integrate.EventGraph at 0x240ff66c550>,
#   <data_integrate.EventGraph at 0x240ff671220>,
#   <data_integrate.EventGraph at 0x240ff690d30>,
#   <data_integrate.EventGraph at 0x240ff6aed60>,
#   <data_integrate.EventGraph at 0x240ff6dd790>,
#   <data_integrate.EventGraph at 0x240ff707640>,
#   <data_integrate.EventGraph at 0x240ff70e310>,
#   <data_integrate.EventGraph at 0x240ff742970>,
#   <data_integrate.EventGraph at 0x240ff760fd0>,
#   <data_integrate.EventGraph at 0x240ff783f40>,
#   <data_integrate.EventGraph at 0x240ff7b9c70>,
#   <data_integrate.EventGraph at 0x240ff7e96a0>,
#   <data_integrate.EventGraph at 0x240ff807d00>,
#   <data_integrate.EventGraph at 0x240ff83ca30>,
#   <data_integrate.EventGraph at 0x240ff8600d0>,
#   <data_integrate.EventGraph at 0x240ff860490>,
#   <data_integrate.EventGraph at 0x240ff87faf0>,
#   <data_integrate.EventGraph at 0x240ff8b4820>,
#   <data_integrate.EventGraph at 0x240ff8e8e80>,
#   <data_integrate.EventGraph at 0x240ff9178b0>,
#   <data_integrate.EventGraph at 0x240ff93d400>,
#   <data_integrate.EventGraph at 0x240ff95ca60>,
#   <data_integrate.EventGraph at 0x240ff979a90>,
#   <data_integrate.EventGraph at 0x240ff99d130>,
#   <data_integrate.EventGraph at 0x240ff9bb790>,
#   <data_integrate.EventGraph at 0x240ff9ea1c0>,
#   <data_integrate.EventGraph at 0x240ffa14bb0>,
#   <data_integrate.EventGraph at 0x240ffa37250>,
#   <data_integrate.EventGraph at 0x240ffa61c40>,
#   <data_integrate.EventGraph at 0x240ffa852e0>,
#   <data_integrate.EventGraph at 0x240ffaa3940>,
#   <data_integrate.EventGraph at 0x240ffac2fa0>,
#   <data_integrate.EventGraph at 0x240ffaf19d0>,
#   <data_integrate.EventGraph at 0x240ffb15940>,
#   <data_integrate.EventGraph at 0x240ffb33fa0>,
#   <data_integrate.EventGraph at 0x240ffb57640>,
#   <data_integrate.EventGraph at 0x240ffb75670>,
#   <data_integrate.EventGraph at 0x240ffba30a0>,
#   <data_integrate.EventGraph at 0x240ffbc3bb0>,
#   <data_integrate.EventGraph at 0x240ffbc3f70>,
#   <data_integrate.EventGraph at 0x240ffbe8ac0>,
#   <data_integrate.EventGraph at 0x240ffc0b610>,
#   <data_integrate.EventGraph at 0x240ffc2ac70>,
#   <data_integrate.EventGraph at 0x240ffc4d7c0>,
#   <data_integrate.EventGraph at 0x240ffc72730>,
#   <data_integrate.EventGraph at 0x240ffc90d90>,
#   <data_integrate.EventGraph at 0x240ffcc4c70>,
#   <data_integrate.EventGraph at 0x240ffceabe0>,
#   <data_integrate.EventGraph at 0x240ffd1a610>,
#   <data_integrate.EventGraph at 0x240ffd4a040>,
#   <data_integrate.EventGraph at 0x240ffd676a0>,
#   <data_integrate.EventGraph at 0x240ffd85d00>,
#   <data_integrate.EventGraph at 0x240ffda9850>,
#   <data_integrate.EventGraph at 0x240ffdc6eb0>,
#   <data_integrate.EventGraph at 0x240ffdf68e0>,
#   <data_integrate.EventGraph at 0x240ffe1b430>,
#   <data_integrate.EventGraph at 0x240ffe44e20>,
#   <data_integrate.EventGraph at 0x240ffe684c0>,
#   <data_integrate.EventGraph at 0x240ffe86fd0>,
#   <data_integrate.EventGraph at 0x240ffeaa670>,
#   <data_integrate.EventGraph at 0x240ffec9cd0>,
#   <data_integrate.EventGraph at 0x240ffecf0d0>,
#   <data_integrate.EventGraph at 0x240ffeeb730>,
#   <data_integrate.EventGraph at 0x240fff10280>,
#   <data_integrate.EventGraph at 0x240fff2e8e0>,
#   <data_integrate.EventGraph at 0x240fff5f310>,
#   <data_integrate.EventGraph at 0x240fff5f6d0>,
#   <data_integrate.EventGraph at 0x240fff94400>,
#   <data_integrate.EventGraph at 0x240fff9c0d0>,
#   <data_integrate.EventGraph at 0x240fffc4ac0>,
#   <data_integrate.EventGraph at 0x240ffff87f0>,
#   <data_integrate.EventGraph at 0x240828316a0>,
#   <data_integrate.EventGraph at 0x24082850d00>]}

# %%
res_dict2 = joblib.load('output/fault_suffering_eventgraphs.joblib')

# %%
res_dict2.keys()
# Out:
# dict_keys(['2022-08-22 03:54', '2022-08-22 03:55', '2022-08-22 04:03', '2022-08-22 04:04', '2022-08-22 04:11', '2022-08-22 04:12', '2022-08-22 04:19', '2022-08-22 04:20', '2022-08-22 04:28', '2022-08-22 04:29', '2022-08-22 04:37', '2022-08-22 04:38', '2022-08-22 04:45', '2022-08-22 04:46', '2022-08-22 04:53', '2022-08-22 04:54', '2022-08-22 05:02', '2022-08-22 05:03', '2022-08-22 05:10', '2022-08-22 05:11', '2022-08-22 05:19', '2022-08-22 05:20', '2022-08-22 05:28', '2022-08-22 05:29', '2022-08-22 05:36', '2022-08-22 05:37', '2022-08-22 05:44', '2022-08-22 05:45', '2022-08-22 05:53', '2022-08-22 05:54', '2022-08-22 06:02', '2022-08-22 06:03', '2022-08-22 06:36', '2022-08-22 06:37', '2022-08-22 06:53', '2022-08-22 06:54', '2022-08-22 07:02', '2022-08-22 07:03', '2022-08-22 07:11', '2022-08-22 07:12', '2022-08-22 07:18', '2022-08-22 07:19', '2022-08-22 07:27', '2022-08-22 07:28', '2022-08-22 07:45', '2022-08-22 07:46', '2022-08-22 07:54', '2022-08-22 07:55', '2022-08-23 12:02', '2022-08-23 12:03', '2022-08-23 12:11', '2022-08-23 12:12', '2022-08-23 12:19', '2022-08-23 12:20', '2022-08-23 12:28', '2022-08-23 12:29', '2022-08-23 12:36', '2022-08-23 12:37', '2022-08-23 12:46', '2022-08-23 12:47', '2022-08-23 12:54', '2022-08-23 12:55', '2022-08-23 13:03', '2022-08-23 13:04', '2022-08-23 13:11', '2022-08-23 13:12', '2022-08-23 13:20', '2022-08-23 13:21', '2022-08-23 13:28', '2022-08-23 13:29', '2022-08-23 13:38', '2022-08-23 13:39', '2022-08-23 13:46', '2022-08-23 13:47', '2022-08-23 13:55', '2022-08-23 13:56', '2022-08-23 14:04', '2022-08-23 14:05', '2022-08-23 14:13', '2022-08-23 14:14', '2022-08-23 14:22', '2022-08-23 14:23', '2022-08-23 14:31', '2022-08-23 14:32', '2022-08-23 14:48', '2022-08-23 14:49', '2022-08-23 14:56', '2022-08-23 14:57', '2022-08-23 15:05', '2022-08-23 15:06', '2022-08-23 15:13', '2022-08-23 15:14', '2022-08-23 15:22', '2022-08-23 15:23', '2022-08-23 15:30', '2022-08-23 15:31', '2022-08-23 15:39', '2022-08-23 15:40', '2022-08-23 15:48', '2022-08-23 15:49', '2022-08-23 15:57', '2022-08-23 15:58', '2022-08-23 16:06', '2022-08-23 16:07', '2022-08-23 16:14', '2022-08-23 16:15', '2022-08-23 16:23', '2022-08-23 16:24', '2022-08-23 16:32', '2022-08-23 16:33', '2022-08-23 16:41', '2022-08-23 16:42'])

# %%
fault_free_pattern = get_pattern_support(res_dict['2022-08-22 03:51'])

# %%
res_dict2['2022-08-22 03:54']['inject_pod']
# Out:
# 'frontend-579b9bff58-t2dbm'

# %%
fault_suffering_event_graphs = res_dict2['2022-08-22 03:54']['event_graphs']
fault_suffering_pattern = get_pattern_support(fault_suffering_event_graphs)

# %%
fault_suffering_event_graphs[0].adjacency_list
# Out:
# {<data_integrate.Event at 0x17e2d7b8700>: [<data_integrate.Event at 0x17e2d7ab430>],
#  <data_integrate.Event at 0x17e2d7ab430>: [<data_integrate.Event at 0x17e2d7abf70>],
#  <data_integrate.Event at 0x17e2d7abf70>: [<data_integrate.Event at 0x17e2d7ab700>],
#  <data_integrate.Event at 0x17e2d7ab700>: [<data_integrate.Event at 0x17e2d79e220>],
#  <data_integrate.Event at 0x17e2d79e220>: [<data_integrate.Event at 0x17e2d79ebb0>],
#  <data_integrate.Event at 0x17e2d79ebb0>: [<data_integrate.Event at 0x17e2d79e520>],
#  <data_integrate.Event at 0x17e2d79e520>: [<data_integrate.Event at 0x17e2d79e640>],
#  <data_integrate.Event at 0x17e2d79e640>: [<data_integrate.Event at 0x17e2d79e9a0>,
#   <data_integrate.Event at 0x17e2d79e6d0>,
#   <data_integrate.Event at 0x17e2d79ed00>,
#   <data_integrate.Event at 0x17e2d79eac0>,
#   <data_integrate.Event at 0x17e2d7a6e20>,
#   <data_integrate.Event at 0x17e2d7a6d90>,
#   <data_integrate.Event at 0x17e2d7a6c40>,
#   <data_integrate.Event at 0x17e2d7a6a60>,
#   <data_integrate.Event at 0x17e2d7a67f0>,
#   <data_integrate.Event at 0x17e2d7a64c0>,
#   <data_integrate.Event at 0x17e2d7a62e0>,
#   <data_integrate.Event at 0x17e2d7a6070>],
#  <data_integrate.Event at 0x17e2d79e6d0>: [<data_integrate.Event at 0x17e2d7a6eb0>,
#   <data_integrate.Event at 0x17e2d793250>],
#  <data_integrate.Event at 0x17e2d79ed00>: [<data_integrate.Event at 0x17e2d793e20>,
#   <data_integrate.Event at 0x17e2d793d90>],
#  <data_integrate.Event at 0x17e2d79eac0>: [<data_integrate.Event at 0x17e2d793a30>,
#   <data_integrate.Event at 0x17e2d793c70>],
#  <data_integrate.Event at 0x17e2d7a6e20>: [<data_integrate.Event at 0x17e2d793760>,
#   <data_integrate.Event at 0x17e2d793640>],
#  <data_integrate.Event at 0x17e2d7a6d90>: [<data_integrate.Event at 0x17e2d7930a0>,
#   <data_integrate.Event at 0x17e2d799f70>],
#  <data_integrate.Event at 0x17e2d7a6c40>: [<data_integrate.Event at 0x17e2d799400>,
#   <data_integrate.Event at 0x17e2d799af0>],
#  <data_integrate.Event at 0x17e2d7a6a60>: [<data_integrate.Event at 0x17e2d799820>,
#   <data_integrate.Event at 0x17e2d7995e0>],
#  <data_integrate.Event at 0x17e2d7a67f0>: [<data_integrate.Event at 0x17e2d7992e0>,
#   <data_integrate.Event at 0x17e2d799b80>],
#  <data_integrate.Event at 0x17e2d7a64c0>: [<data_integrate.Event at 0x17e2d78cd90>,
#   <data_integrate.Event at 0x17e2d78c1c0>],
#  <data_integrate.Event at 0x17e2d7a62e0>: [<data_integrate.Event at 0x17e2d78cb50>,
#   <data_integrate.Event at 0x17e2d78cac0>],
#  <data_integrate.Event at 0x17e2d7a6070>: [<data_integrate.Event at 0x17e2d78c640>,
#   <data_integrate.Event at 0x17e2d78c9a0>],
#  <data_integrate.Event at 0x17e2d793250>: [<data_integrate.Event at 0x17e2d78cfd0>],
#  <data_integrate.Event at 0x17e2d78cfd0>: [<data_integrate.Event at 0x17e2d78c0a0>],
#  <data_integrate.Event at 0x17e2d78c0a0>: [<data_integrate.Event at 0x17e2d78c5b0>],
#  <data_integrate.Event at 0x17e2d7812b0>: [<data_integrate.Event at 0x17e2d781f70>],
#  <data_integrate.Event at 0x17e2d781f70>: [<data_integrate.Event at 0x17e2d781e20>],
#  <data_integrate.Event at 0x17e2d781e20>: [<data_integrate.Event at 0x17e2d781af0>],
#  <data_integrate.Event at 0x17e2d799af0>: [<data_integrate.Event at 0x17e2d781910>],
#  <data_integrate.Event at 0x17e2d781910>: [<data_integrate.Event at 0x17e2d781190>],
#  <data_integrate.Event at 0x17e2d781190>: [<data_integrate.Event at 0x17e2d781cd0>],
#  <data_integrate.Event at 0x17e2d7995e0>: [<data_integrate.Event at 0x17e2d769e80>],
#  <data_integrate.Event at 0x17e2d769e80>: [<data_integrate.Event at 0x17e2d769fa0>],
#  <data_integrate.Event at 0x17e2d769fa0>: [<data_integrate.Event at 0x17e2d769a90>],
#  <data_integrate.Event at 0x17e2d799b80>: [<data_integrate.Event at 0x17e2d769bb0>],
#  <data_integrate.Event at 0x17e2d769bb0>: [<data_integrate.Event at 0x17e2d7693d0>],
#  <data_integrate.Event at 0x17e2d7693d0>: [<data_integrate.Event at 0x17e2d769610>],
#  <data_integrate.Event at 0x17e2d78c1c0>: [<data_integrate.Event at 0x17e2d769460>],
#  <data_integrate.Event at 0x17e2d769460>: [<data_integrate.Event at 0x17e2d7692b0>],
#  <data_integrate.Event at 0x17e2d7692b0>: [<data_integrate.Event at 0x17e2d7696a0>],
#  <data_integrate.Event at 0x17e2d78cac0>: [<data_integrate.Event at 0x17e2d774f10>],
#  <data_integrate.Event at 0x17e2d774f10>: [<data_integrate.Event at 0x17e2d774df0>],
#  <data_integrate.Event at 0x17e2d774df0>: [<data_integrate.Event at 0x17e2d774fa0>],
#  <data_integrate.Event at 0x17e2d774850>: [<data_integrate.Event at 0x17e2d774730>],
#  <data_integrate.Event at 0x17e2d774970>: [<data_integrate.Event at 0x17e2d774340>],
#  <data_integrate.Event at 0x17e2d774100>: [<data_integrate.Event at 0x17e2d774460>],
#  <data_integrate.Event at 0x17e2d77bfa0>: [<data_integrate.Event at 0x17e2d77b850>],
#  <data_integrate.Event at 0x17e2d77b460>: [<data_integrate.Event at 0x17e2d77b8e0>],
#  <data_integrate.Event at 0x17e2d77b970>: [<data_integrate.Event at 0x17e2d77b070>],
#  <data_integrate.Event at 0x17e2d77b190>: [<data_integrate.Event at 0x17e2d77b2b0>],
#  <data_integrate.Event at 0x17e2d77bc40>: [<data_integrate.Event at 0x17e2d77bbb0>],
#  <data_integrate.Event at 0x17e2d787d00>: [<data_integrate.Event at 0x17e2d787910>],
#  <data_integrate.Event at 0x17e2d7877c0>: [<data_integrate.Event at 0x17e2d787400>],
#  <data_integrate.Event at 0x17e2d787370>: [<data_integrate.Event at 0x17e2d787850>],
#  <data_integrate.Event at 0x17e2d787be0>: [<data_integrate.Event at 0x17e2d787040>],
#  <data_integrate.Event at 0x17e2d787f40>: [<data_integrate.Event at 0x17e2d770580>],
#  <data_integrate.Event at 0x17e2d770fa0>: [<data_integrate.Event at 0x17e2d770e80>],
#  <data_integrate.Event at 0x17e2d793d90>: [<data_integrate.Event at 0x17e2d770cd0>],
#  <data_integrate.Event at 0x17e2d770cd0>: [<data_integrate.Event at 0x17e2d770b20>],
#  <data_integrate.Event at 0x17e2d770970>: [<data_integrate.Event at 0x17e2d770460>],
#  <data_integrate.Event at 0x17e2d770460>: [<data_integrate.Event at 0x17e2d7702b0>],
#  <data_integrate.Event at 0x17e2d7702b0>: [<data_integrate.Event at 0x17e2d770220>],
#  <data_integrate.Event at 0x17e2d793c70>: [<data_integrate.Event at 0x17e2d763fa0>],
#  <data_integrate.Event at 0x17e2d763fa0>: [<data_integrate.Event at 0x17e2d763d60>],
#  <data_integrate.Event at 0x17e2d793640>: [<data_integrate.Event at 0x17e2d763a00>],
#  <data_integrate.Event at 0x17e2d763a00>: [<data_integrate.Event at 0x17e2d7637c0>],
#  <data_integrate.Event at 0x17e2d7637c0>: [<data_integrate.Event at 0x17e2d763970>],
#  <data_integrate.Event at 0x17e2d7633a0>: [<data_integrate.Event at 0x17e2d763280>],
#  <data_integrate.Event at 0x17e2d763280>: [<data_integrate.Event at 0x17e2d763730>],
#  <data_integrate.Event at 0x17e2d763730>: [<data_integrate.Event at 0x17e2d7638e0>],
#  <data_integrate.Event at 0x17e2d752fd0>: [<data_integrate.Event at 0x17e2d752a30>],
#  <data_integrate.Event at 0x17e2d752a30>: [<data_integrate.Event at 0x17e2d7522e0>],
#  <data_integrate.Event at 0x17e2d752250>: [<data_integrate.Event at 0x17e2d752eb0>],
#  <data_integrate.Event at 0x17e2d752eb0>: [<data_integrate.Event at 0x17e2d752ac0>],
#  <data_integrate.Event at 0x17e2d799f70>: [<data_integrate.Event at 0x17e2d752880>],
#  <data_integrate.Event at 0x17e2d752880>: [<data_integrate.Event at 0x17e2d752640>],
#  <data_integrate.Event at 0x17e2d752640>: [<data_integrate.Event at 0x17e2d752d90>],
#  <data_integrate.Event at 0x17e2d757dc0>: [<data_integrate.Event at 0x17e2d757b20>,
#   <data_integrate.Event at 0x17e2d7812b0>],
#  <data_integrate.Event at 0x17e2d757ee0>: [<data_integrate.Event at 0x17e2d757820>],
#  <data_integrate.Event at 0x17e2d757820>: [<data_integrate.Event at 0x17e2d757160>],
#  <data_integrate.Event at 0x17e2d757160>: [<data_integrate.Event at 0x17e2d757070>],
#  <data_integrate.Event at 0x17e2d7578b0>: [<data_integrate.Event at 0x17e2d757490>],
#  <data_integrate.Event at 0x17e2d757490>: [<data_integrate.Event at 0x17e2d75ebb0>],
#  <data_integrate.Event at 0x17e2d75ebb0>: [<data_integrate.Event at 0x17e2d75ed90>],
#  <data_integrate.Event at 0x17e2d75ed90>: [<data_integrate.Event at 0x17e2d75e7f0>],
#  <data_integrate.Event at 0x17e2d75e7f0>: [<data_integrate.Event at 0x17e2d75e4c0>],
#  <data_integrate.Event at 0x17e2d75e4c0>: [<data_integrate.Event at 0x17e2d75e2e0>],
#  <data_integrate.Event at 0x17e2d75e2e0>: [<data_integrate.Event at 0x17e2d75e100>],
#  <data_integrate.Event at 0x17e2d75e100>: [<data_integrate.Event at 0x17e2d75e760>],
#  <data_integrate.Event at 0x17e2d75e760>: [<data_integrate.Event at 0x17e2d75e940>],
#  <data_integrate.Event at 0x17e2d75e940>: [<data_integrate.Event at 0x17e2d7b2d30>],
#  <data_integrate.Event at 0x17e2d7b2d30>: [<data_integrate.Event at 0x17e2d7b2dc0>],
#  <data_integrate.Event at 0x17e2d78c9a0>: [<data_integrate.Event at 0x17e2d7b2670>],
#  <data_integrate.Event at 0x17e2d7b25e0>: [<data_integrate.Event at 0x17e2d7b2820>],
#  <data_integrate.Event at 0x17e2d7b2820>: [<data_integrate.Event at 0x17e2d7b23a0>],
#  <data_integrate.Event at 0x17e2d7b23a0>: [<data_integrate.Event at 0x17e2d7b20d0>,
#   <data_integrate.Event at 0x17e2d7b2280>,
#   <data_integrate.Event at 0x17e2d74be20>],
#  <data_integrate.Event at 0x17e2d7b2280>: [<data_integrate.Event at 0x17e2d74bd90>],
#  <data_integrate.Event at 0x17e2d74bd90>: [<data_integrate.Event at 0x17e2d74bf40>],
#  <data_integrate.Event at 0x17e2d74bf40>: [<data_integrate.Event at 0x17e2d74b880>],
#  <data_integrate.Event at 0x17e2d74b880>: [<data_integrate.Event at 0x17e2d74b5b0>],
#  <data_integrate.Event at 0x17e2d74b5b0>: [<data_integrate.Event at 0x17e2d74b760>,
#   <data_integrate.Event at 0x17e2d74b0a0>],
#  <data_integrate.Event at 0x17e2d74be20>: [<data_integrate.Event at 0x17e2d74b370>],
#  <data_integrate.Event at 0x17e2d74b370>: [<data_integrate.Event at 0x17e2d74bac0>],
#  <data_integrate.Event at 0x17e2d74bac0>: [<data_integrate.Event at 0x17e2d73af40>],
#  <data_integrate.Event at 0x17e2d73af40>: [<data_integrate.Event at 0x17e2d73ac70>],
#  <data_integrate.Event at 0x17e2d73ac70>: [<data_integrate.Event at 0x17e2d73ad90>,
#   <data_integrate.Event at 0x17e2d73a880>],
#  <data_integrate.Event at 0x17e2d74b0a0>: [<data_integrate.Event at 0x17e2d73a7f0>],
#  <data_integrate.Event at 0x17e2d73a880>: [<data_integrate.Event at 0x17e2d73a5b0>]}

# %%
fault_suffering_pattern
# Out:
# {'44_44': 3184,
#  '47_48': 2649,
#  '49_50': 2649,
#  '36_37': 2251,
#  '37_37': 2251,
#  '37_38': 2251,
#  '5_12': 2213,
#  '12_13': 2213,
#  '12_36': 2213,
#  '73_74': 2198,
#  '74_75': 2198,
#  '19_20': 1497,
#  '20_21': 1497,
#  '21_22': 1497,
#  '5_67': 1099,
#  '67_68': 1099,
#  '67_69': 1099,
#  '69_70': 1099,
#  '70_71': 1099,
#  '71_72': 1099,
#  '1_2': 503,
#  '4_5': 503,
#  '5_184': 503,
#  '5_6': 398,
#  '6_7': 398,
#  '6_16': 398,
#  '32_33': 398,
#  '33_34': 398,
#  '34_35': 398,
#  '16_17': 398,
#  '17_18': 398,
#  '23_24': 398,
#  '24_25': 398,
#  '39_40': 398,
#  '40_41': 398,
#  '41_42': 398,
#  '43_44': 398,
#  '44_45': 398,
#  '45_46': 398,
#  '5_8': 386,
#  '8_9': 386,
#  '8_23': 386,
#  '97_98': 353,
#  '5_10': 339,
#  '10_11': 339,
#  '10_26': 339,
#  '26_27': 339,
#  '27_28': 339,
#  '28_29': 339,
#  '30_31': 339,
#  '30_32': 339,
#  '91_93': 294,
#  '93_94': 294,
#  '94_94': 294,
#  '94_95': 294,
#  '95_96': 294,
#  '96_92': 294,
#  '96_97': 294,
#  '83_84': 282,
#  '5_85': 282,
#  '85_86': 282,
#  '85_87': 282,
#  '87_88': 282,
#  '90_91': 282,
#  '91_92': 282,
#  '2_82': 223,
#  '82_83': 223,
#  '84_82': 223,
#  '82_4': 223,
#  '89_90': 223,
#  '51_52': 116,
#  '52_53': 116,
#  '53_54': 116,
#  '55_56': 116,
#  '56_57': 116,
#  '57_58': 116,
#  '59_60': 116,
#  '60_61': 116,
#  '61_62': 116,
#  '63_64': 116,
#  '64_65': 116,
#  '65_66': 116,
#  '2_3': 104,
#  '3_3': 104,
#  '3_4': 104,
#  '5_14': 104,
#  '14_15': 104,
#  '14_51': 104,
#  '2_76': 65,
#  '76_76': 65,
#  '76_4': 65,
#  '5_77': 65,
#  '77_78': 65,
#  '77_79': 65,
#  '79_80': 65,
#  '80_81': 65,
#  '2_99': 59,
#  '99_83': 59,
#  '84_100': 59,
#  '100_4': 59,
#  '5_101': 59,
#  '101_102': 59,
#  '101_32': 59,
#  '89_103': 59,
#  '103_104': 59,
#  '104_90': 59,
#  '91_105': 59,
#  '105_95': 59,
#  '95_106': 59,
#  '106_92': 59,
#  '106_97': 59,
#  '145_146': 50,
#  '146_147': 50,
#  '147_148': 50,
#  '2_107': 40,
#  '107_108': 40,
#  '108_4': 40,
#  '121_122': 38,
#  '121_36': 38,
#  '2_109': 12,
#  '109_110': 12,
#  '110_4': 12,
#  '5_111': 12,
#  '111_112': 12,
#  '111_113': 12,
#  '113_114': 12,
#  '114_115': 12,
#  '115_116': 12,
#  '116_117': 12,
#  '117_118': 12,
#  '119_120': 12,
#  '119_23': 12,
#  '123_124': 12,
#  '123_51': 12,
#  '125_126': 12,
#  '125_175': 12,
#  '127_128': 12,
#  '127_171': 12,
#  '129_130': 12,
#  '129_169': 12,
#  '131_132': 12,
#  '131_179': 12,
#  '133_134': 12,
#  '134_135': 12,
#  '135_136': 12,
#  '137_138': 12,
#  '138_139': 12,
#  '139_140': 12,
#  '141_142': 12,
#  '142_143': 12,
#  '143_144': 12,
#  '149_150': 12,
#  '150_151': 12,
#  '151_152': 12,
#  '153_154': 12,
#  '154_155': 12,
#  '155_156': 12,
#  '157_158': 12,
#  '158_159': 12,
#  '159_160': 12,
#  '161_162': 12,
#  '162_163': 12,
#  '163_164': 12,
#  '165_166': 12,
#  '166_167': 12,
#  '167_168': 12,
#  '169_24': 12,
#  '24_170': 12,
#  '171_172': 12,
#  '172_173': 12,
#  '173_174': 12,
#  '175_176': 12,
#  '176_177': 12,
#  '177_178': 12,
#  '179_180': 12,
#  '180_181': 12,
#  '181_182': 12}

# %%
pattern_ranker_custom(fault_free_pattern, fault_suffering_event_graphs, fault_suffering_pattern, log_template_miner)
# Out:
# [{'events': '5_12',
#   'score': 2213,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_67',
#   'score': 1099,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_184',
#   'score': 503,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_6',
#   'score': 398,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_8',
#   'score': 386,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_10',
#   'score': 339,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '5_85',
#   'score': 282,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '73_74',
#   'score': -156,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '47_48',
#   'score': 104,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'},
#  {'events': '49_50',
#   'score': 104,
#   'deepth': 1,
#   'pod': 'frontend-579b9bff58-t2dbm'}]
