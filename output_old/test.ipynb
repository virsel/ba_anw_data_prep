# %%
import pandas as pd

df = pd.read_csv("features_labeled_4llm_v1.csv")

# %%
df.columns
# Out:
# Index(['abnormal_time', 'abnormalpattern_noerror_ranked_prompt',
#        'abnormalpattern_error_ranked_prompt', 'inject_time', 'inject_pod',
#        'inject_type'],
#       dtype='object')

# %%
pd.set_option("")

mask = df.inject_type == "return"

df[mask]
# Out:
#         abnormal_time     ...     inject_type
# 2    2022-08-22 04:03     ...          return
# 3    2022-08-22 04:04     ...          return
# 18   2022-08-22 05:10     ...          return
# 19   2022-08-22 05:11     ...          return
# 44   2022-08-22 07:45     ...          return
# 45   2022-08-22 07:46     ...          return
# 50   2022-08-23 12:11     ...          return
# 51   2022-08-23 12:12     ...          return
# 64   2022-08-23 13:11     ...          return
# 65   2022-08-23 13:12     ...          return
# 84   2022-08-23 14:48     ...          return
# 85   2022-08-23 14:49     ...          return
# 104  2022-08-23 16:14     ...          return
# 105  2022-08-23 16:15     ...          return
#
# [14 rows x 6 columns]
